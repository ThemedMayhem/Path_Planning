# %% [markdown]
# # Path Planning On a Grid

# %% [markdown]
# ![1](./Image/1.png)

# %% [markdown]
# In this lab we consider the problem of finding a (shortest) path on a graph of special structure, widely used in robotics and computer games, i.e. a grid. Grid is composed of the free and blocked cells and an agent may move from one free cell to the other. The connectivity of the grid may vary, e.g. grid might be 4-connected when only cardinal moves are allowed, 8-connected when diagonal moves are allowed as well, etc.
#
# **In this lab we assume that the grid can be either 4-connected or 8-connected**. When grid is 4-connected only moves into the cardinal directions (N,E,W,S) are allowed. The cost of each move is uniform, i.e. 1. When grid is 8-connected diagonal moves are additionally allowed. The cost of diagonal moves is sqrt(2).
#
# We will consider two algorithms for grid-based pathfinding: `Dijkstra`'s algorithm and `A*`. Both of these algorithms can be implemented in a way that the difference might seem negligible. I.e. `Dijkstra`'s algorithm uses g-values to prioritize search-nodes in OPEN, while `A*` do this by utilizing f-values, where f(n)=g(n)+h(n), where h(n) is an admissible heuristic. This subtle difference, however, might severely influence the performance as will see further on.
#
# So let's go for it!

# %% [markdown]
# ![2](./Image/2.png)

# %% [markdown]
# You task is to implement `Dijkstra` and `A*` by filling up the missing parts of the code.
#
# Run every cell of the notebook, completing the tasks described in them. Good luck!

# %%
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt
import math
from sys import float_info
EPS = float_info.epsilon
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive/')
# !ls
# Out:
# Mounted at /content/drive/
# drive  sample_data

# %%
# %cd /content/drive/My Drive/Planning/Lab1/
# !ls
# Out:
# /content/drive/My Drive/Planning/Lab1
# Data  Image  Lab11.ipynb  Lab1.ipynb

# %% [markdown]
# ### Grid map representation
#
# Square grid map class represents the environment for our moving agent
#
# - width -- the number of columns in the grid
# - height -- the number of rows in the grid
# - cells -- the binary matrix, that represents the grid. 0 - cell is traversable, 1 - cell is blocked

# %%
class Map:

    # 
    def __init__(self):
        '''
        Default constructor
        '''

        self.width = 0
        self.height = 0
        self.cells = []
    

    def ReadFromString(self, cellStr, width, height):
        '''
        Converting a string (with '#' representing obstacles and '.' representing free cells) to a grid
        '''
        self.width = width
        self.height = height
        self.cells = [[0 for _ in range(width)] for _ in range(height)]
        cellLines = cellStr.split("\n")
        i = 0
        j = 0
        for l in cellLines:
            if len(l) != 0:
                j = 0
                for c in l:
                    if c == '.':
                        self.cells[i][j] = 0
                    elif c == '#':
                        self.cells[i][j] = 1
                    else:
                        continue
                    j += 1
                if j != width:
                    raise Exception("Size Error. Map width = ", j, ", but must be", width )
                
                i += 1

        if i != height:
            raise Exception("Size Error. Map height = ", i, ", but must be", height )
    
     
    def SetGridCells(self, width, height, gridCells):
        '''
        Initialization of map by list of cells.
        '''
        self.width = width
        self.height = height
        self.cells = gridCells


    def inBounds(self, i, j):
        '''
        Check if the cell is on a grid.
        '''
        return (0 <= j < self.width) and (0 <= i < self.height)
    

    def Traversable(self, i, j):
        '''
        Check if the cell is not an obstacle.
        '''
        return not self.cells[i][j]


    def GetNeighbors(self, i, j, diagonalMoves = False):
        '''
        Get a list of neighbouring cells as (i,j) tuples.
        '''   

        neighbors = []

      
        deltas = [(0,1),(1,0),(-1,0),(0,-1)]
        for d in deltas:
            if self.inBounds(i+d[0], j+d[1]) and self.Traversable(i+d[0], j + d[1]):
              neighbors.append((i+ d[0], j + d[1]))

        deltasdig = [(1,1),(1,-1),(-1,1),(-1,-1)]
        if diagonalMoves:
         for d in deltas:
            if (self.inBounds(i, j + d[1]) and self.inBounds(i + d[0], j ) and self.Traversable(i + d[0], j) and self.Traversable(i , j + d[1]) and self.inBounds(i + d[0], j + d[1]) and self.Traversable(i + d[0], j + d[1])):
                neighbors.append((i + d[0], j + d[1]))

        #TODO
        return neighbors

# %% [markdown]
# Computes the cost of a transition from cell `(i1, j1)` to cell `(i2, j2)`. In case of 4-connected grid it is always equal to 1. However if other moves are allowed, the cost of a transition may vary.

# %%
def ComputeCost(i1, j1, i2, j2):
    '''
    Computes cost of simple moves between cells
    '''
    if abs(i1 - i2) + abs(j1 - j2) == 1: #cardinal move
        return 1
    else: #diagonal move
        return math.sqrt(2)

# %% [markdown]
# ### Search Node Representation

# %%
class Node:
    '''
    Node class represents a search node

    - i, j: coordinates of corresponding grid element
    - g: g-value of the node
    - h: h-value of the node
    - F: f-value of the node
    - parent: pointer to the parent-node 

    You might want to add other fields, methods for Node, depending on how you prefer to implement OPEN/CLOSED further on
    '''

    def __init__(self, i, j, g = 0, h = 0, F = None, parent = None):
        self.i = i
        self.j = j
        self.g = g
        self.h = h
        if F is None:
            self.F = self.g + h
        else:
            self.F = F        
        self.parent = parent
    
    
    def __eq__(self, other):
        return (self.i == other.i) and (self.j == other.j)
    
    def __lt__(self, other): #self < other (self has higher priority)
        return self.F < other.F or (abs(self.F - other.F) < EPS and (self.g > other.g))

# %% [markdown]
# ### Visualization

# %% [markdown]
# Example of the visualization

# %%
def Draw(gridMap : Map, start : Node = None, goal : Node = None, path : list = None, nodesExpanded = None, nodesOpened = None):
    '''
    Auxiliary function that visualizes the enviromnet, the path and OPEN and CLOSED.
    '''
    k = 5
    hIm = gridMap.height * k
    wIm = gridMap.width * k
    im = Image.new('RGB', (wIm, hIm), color = 'white')
    draw = ImageDraw.Draw(im)
    for i in range(gridMap.height):
        for j in range(gridMap.width):
            if(gridMap.cells[i][j] == 1):
                draw.rectangle((j * k, i * k, (j + 1) * k - 1, (i + 1) * k - 1), fill=( 70, 80, 80 ))

    if nodesOpened is not None:
        if (type(nodesOpened) == type(YourOpen())):
            for h, node in nodesOpened.elements.items():
                draw.rectangle((node.j * k, node.i * k, (node.j + 1) * k - 1, (node.i + 1) * k - 1), fill=(213, 219, 219), width=0)
        else:
            for node in nodesOpened:
                draw.rectangle((node.j * k, node.i * k, (node.j + 1) * k - 1, (node.i + 1) * k - 1), fill=(213, 219, 219), width=0)

    if nodesExpanded is not None:
        if (type(nodesExpanded) == type(YourClosed())):
            for h, node in nodesExpanded.elements.items():
                draw.rectangle((node.j * k, node.i * k, (node.j + 1) * k - 1, (node.i + 1) * k - 1), fill=( 131, 145, 146 ), width=0)
        else:
            for node in nodesExpanded:
                draw.rectangle((node.j * k, node.i * k, (node.j + 1) * k - 1, (node.i + 1) * k - 1), fill=( 131, 145, 146 ), width=0)

    if path is not None:
        for step in path:
            if (step is not None):
                if (gridMap.Traversable(step.i, step.j)):
                    draw.rectangle((step.j * k, step.i * k, (step.j + 1) * k - 1, (step.i + 1) * k - 1), fill=(52, 152, 219), width=0)
                else:
                    draw.rectangle((step.j * k, step.i * k, (step.j + 1) * k - 1, (step.i + 1) * k - 1), fill=(230, 126, 34), width=0)

    if (start is not None) and (gridMap.Traversable(start.i, start.j)):
        draw.rectangle((start.j * k, start.i * k, (start.j + 1) * k - 1, (start.i + 1) * k - 1), fill=(40, 180, 99), width=0)
    
    if (goal is not None) and (gridMap.Traversable(goal.i, goal.j)):
        draw.rectangle((goal.j * k, goal.i * k, (goal.j + 1) * k - 1, (goal.i + 1) * k - 1), fill=(231, 76, 60), width=0)


    fig, ax = plt.subplots(dpi=150)
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    plt.imshow(np.asarray(im))

# %%
height = 15
width = 30
mapstr = '''
. . . . . . . . . . . . . . . . . . . . . # # . . . . . . .  
. . . . . . . . . . . . . . . . . . . . . # # . . . . . . . 
. . . . . . . . . . . . . . . . . . . . . # # . . . . . . . 
. . . # # . . . . . . . . . . . . . . . . # # . . . . . . . 
. . . # # . . . . . . . . # # . . . . . . # # . . . . . . . 
. . . # # . . . . . . . . # # . . . . . . # # # # # . . . . 
. . . # # . . . . . . . . # # . . . . . . # # # # # . . . . 
. . . # # . . . . . . . . # # . . . . . . . . . . . . . . . 
. . . # # . . . . . . . . # # . . . . . . . . . . . . . . . 
. . . # # . . . . . . . . # # . . . . . . . . . . . . . . . 
. . . # # . . . . . . . . # # . . . . . . . . . . . . . . . 
. . . # # . . . . . . . . # # . . . . . . . . . . . . . . . 
. . . . . . . . . . . . . # # . . . . . . . . . . . . . . . 
. . . . . . . . . . . . . # # . . . . . . . . . . . . . . .
. . . . . . . . . . . . . # # . . . . . . . . . . . . . . .
'''

testMap = Map()
testMap.ReadFromString(mapstr, width, height)
start = Node(2, 26)
goal = Node(13, 1)
Draw(testMap, start, goal)

# %% [markdown]
# ### Implementing OPEN and CLOSED
# Efficient implementation of OPEN and CLOSED is crucial for any search algorithm. Below you may find basic implementations that use lists to store the elements of OPEN and CLOSED. This is not very efficient. Your task is to create your own implementations.
#
# It's a good idea to modify CLOSED first (as it is pretty straghtforward to do so). Then check that everything is OK, i.e. the search algorithms work faster and the result is correct. Then proceed to modifying OPEN (which is not that trivial as might seem).
#
# PS: You may wish to add additional fields, methods, method-arguments etc. to your implementations.

# %%
class OpenBase:

    def __init__(self):
        pass


    def __len__(self):
        pass


    def __iter__(self):
        pass


    def isEmpty(self):
        '''
        isEmpty should inform whether the OPEN is exhausted or not in the former case the search main loop should be interrupted
        '''
        pass


    def AddNode(self, node : Node, *args):
        '''
        AddNode is the method that puts (e.g. inserts or updates) the node to OPEN
        When implementing it do not forget to handle all possible cases:
         - node already in OPEN but the new g-value is better;
         - node already in OPEN but the new g-value is worse;
         - node is not in OPEN yet.
        '''
        pass


    def GetBestNode(self, *args):
        '''
        GetBestNode is the method that 
         i) finds the best node, i.e. the one with the lowest f-value (f=g+h) (for Dijkstra h=0),
         ii) removes it from OPEN and 
         iii) returns it
        '''
        pass

# %%
class OpenList (OpenBase):

    def __init__(self):
        self.elements = []
    

    def __iter__(self):
        return iter(self.elements)


    def __len__(self):
        return len(self.elements)


    def isEmpty(self):
        if len(self.elements) != 0:
            return False
        return True
    

    def GetBestNode(self, *args):
        bestF = math.inf
        bestCoord = 0
        for i in range(len(self.elements)):
            if self.elements[i].F < bestF:
                bestCoord = i
                bestF = self.elements[i].F
                
        best = self.elements.pop(bestCoord)
        return best
    

    def AddNode(self, node : Node, *args):
        for existingNode in self.elements:
            if existingNode.i == node.i and existingNode.j == node.j:
                if existingNode.g > node.g:
                    existingNode.g = node.g
                    existingNode.F = node.F
                    existingNode.parent = node.parent
                    return
                else:
                    return
        self.elements.append(node)
        return

# %%
class ClosedBase:

    def __init__(self):
        pass


    def __iter__(self):
        pass
    

    def __len__(self):
        pass
    
    
    def AddNode(self, item : Node):
        pass


    def WasExpanded(self, item : Node):
        pass

# %%
class ClosedList (ClosedBase):

    
    def __init__(self):
        self.elements = []


    def __iter__(self):
        return iter(self.elements)
    

    def __len__(self):
        return len(self.elements)
    

    def AddNode(self, item : Node):
        '''
        AddNode is the method that inserts the node to CLOSED
        '''
        self.elements.append(item)
     
     
    def WasExpanded(self, item : Node):
        '''
        WasExpanded is the method that checks if a node has been expanded
        '''
        return item in self.elements

# %%
class YourOpen (OpenBase):

    def __init__(self):
        self.elements = dict()
        self.sortF = dict()


    def __iter__(self):
        return iter(self.elements)


    def __len__(self):
        return len(self.elements)


    def isEmpty(self):
        return self.__len__() == 0

    def GetBestNode(self, *args):
        mn = min(self.sortF)
        k = self.sortF[mn][0]
        if (len(self.sortF[mn])) == 1:
            self.sortF.pop(mn)
        else:
            self.sortF.update({mn: self.sortF[mn][1:]})
        best = self.elements.pop(k)
        return best

    def AddNode(self, node : Node, *args):
        el = self.elements.get((node.i, node.j))
        if el:
            if el.g > node.g:
                mn = el.F
                self.elements[(node.i, node.j)] = Node(node.i, node.j, node.g, node.h, node.F, node.parent)
                self.sortF[mn].remove((node.i, node.j))
                if (len(self.sortF[mn]) == 0):
                    self.sortF.pop(mn)

                if self.sortF.get(node.F):
                    self.sortF.update({node.F: self.sortF[node.F] + [(node.i, node.j)]})
                else:
                    self.sortF.update({node.F: [(node.i, node.j)]})
            return
        self.elements.update({(node.i, node.j): node})

        if self.sortF.get(node.F):
            self.sortF.update({node.F: self.sortF[node.F] + [(node.i, node.j)]})
        else:
            self.sortF.update({node.F: [(node.i, node.j)]})
        return

# %%
class YourClosed (ClosedBase):
    '''
    # !!!TODO!!!
    Create your own modification of CLOSED#
    '''

    def __init__(self):
        self.elements = dict()


    def __iter__(self):
        return iter(self.elements)
    

    def __len__(self):
        return len(self.elements)


    def AddNode(self, item : Node):
        self.elements.update({(item.i, item.j): item})


    def WasExpanded(self, item : Node):
        return (item.i, item.j) in self.elements

# %% [markdown]
# ### Validating the results

# %%
def MakePath(goal):
    '''
    Creates a path by tracing parent pointers from the goal node to the start node
    It also returns path's length.
    '''

    length = goal.g
    current = goal
    path = []
    while current.parent:
        path.append(current)
        current = current.parent
    path.append(current)
    return path[::-1], length

# %%
def ReadTaskFromFile(path):
    '''
    Reads map, start/goal positions and true value of path length between given start and goal from file by path. 
    '''

    tasksFile = open(path)
    count = 0
    height = int(tasksFile.readline())
    width = int(tasksFile.readline())
    cells = [[0 for _ in range(width)] for _ in range(height)]
    i = 0
    j = 0

    for l in tasksFile:
        j = 0
        for c in l:
            if c == '.':
                cells[i][j] = 0
            elif c == '#':
                cells[i][j] = 1
            else:
                continue
            
            j += 1
            
        if j != width:
            raise Exception("Size Error. Map width = ", j, ", but must be", width, "(map line: ", i, ")")
                
        i += 1
        if(i == height):
            break
    
    iStart = int(tasksFile.readline())
    jStart = int(tasksFile.readline())
    iGoal = int(tasksFile.readline())
    jGoal = int(tasksFile.readline())
    cardinalLength = float(tasksFile.readline())
    diagonalLength = float(tasksFile.readline())
    return (width, height, cells, iStart, jStart, iGoal, jGoal, cardinalLength, diagonalLength)

# %% [markdown]
# `Simpletest` tests the pathfing algorithm on a single simple instance, `Massivetest` - on a series of a move involved instances. Both tests assume that the search function fits the following pattern:
#
#
# `Search(taskMap, start.i, start.j, goal.i, goal.j, *optional arguments*) -> (pathFound, lastState, CLOSED, OPEN)`, where
#
# - taskMap -- grid
# - start.i, start.j -- (i,j) coordinates of the start cell
# - goal.i, goal.j -- (i,j) coordinates of the goal cell
# - *optional arguments* -- additional parameters of the search function, passed with `*args`. Example of additional parameters you can see at Dijkstra and A* functions
# - pathFound -- `True` if path was found, `False` otherwise
# - lastState -- last state of the path. `None` if path was not found
# - CLOSED -- CLOSED set (at the last step)
# - OPEN -- OPEN set (at the last step)

# %%
from random import randint

def SimpleTest(SearchFunction, task, *args):
    '''
    SimpleTest runs SearchFunction on one task (use a number from 0 to 25 to choose a certain debug task on simple map or None to choose a random task from this pool) with *args as optional arguments and displays:
     - 'Path found!' and some statistics -- path was found
     - 'Path not found!' -- path was not found
     - 'Execution error' -- an error occurred while executing the SearchFunction In first two cases function also draws visualisation of the task

    '''
    
    height = 15
    width = 30
    mapstr = '''
. . . . . . . . . . . . . . . . . . . . . # # . . . . . . .  
. . . . . . . . . . . . . . . . . . . . . # # . . . . . . . 
. . . . . . . . . . . . . . . . . . . . . # # . . . . . . . 
. . . # # . . . . . . . . . . . . . . . . # # . . . . . . . 
. . . # # . . . . . . . . # # . . . . . . # # . . . . . . . 
. . . # # . . . . . . . . # # . . . . . . # # # # # . . . . 
. . . # # . . . . . . . . # # . . . . . . # # # # # . . . . 
. . . # # . . . . . . . . # # . . . . . . . . . . . . . . . 
. . . # # . . . . . . . . # # . . . . . . . . . . . . . . . 
. . . # # . . . . . . . . # # . . . . . . . . . . . . . . . 
. . . # # . . . . . . . . # # . . . . . . . . . . . . . . . 
. . . # # . . . . . . . . # # . . . . . . . . . . . . . . . 
. . . . . . . . . . . . . # # . . . . . . . . . . . . . . . 
. . . . . . . . . . . . . # # . . . . . . . . . . . . . . .
. . . . . . . . . . . . . # # . . . . . . . . . . . . . . .
'''

    taskMap = Map()
    taskMap.ReadFromString(mapstr, width, height)
    starts = [(9, 0), (13, 0), (7, 28), (14, 29), (4, 1), (0, 17), (5, 6), (5, 20), (12, 2), (7, 28), (11, 9), (3, 2), (3, 17), (13, 20), (1, 1), (9, 10), (14, 6), (2, 0), (9, 28), (8, 6), (11, 6), (3, 0), (8, 9), (14, 7), (12, 4)]
    goals = [(11, 20), (2, 19), (6, 5), (4, 18), (9, 20), (7, 0), (2, 25), (12, 4), (3, 25), (0, 12), (4, 23), (2, 24), (9, 2), (1, 6), (13, 29), (14, 29), (2, 28), (14, 16), (13, 0), (1, 27), (14, 25), (10, 20), (12, 28), (2, 29), (1, 29)]
    cardLengths = [36, 30, 30, 21, 28, 24, 32, 27, 42, 23, 35, 37, 23, 26, 40, 36, 42, 28, 44, 36, 38, 29, 33, 42, 44]
    diagLengths = [31.313708498984763, 24.72792206135786, 25.89949493661167, 15.727922061357859, 23.899494936611667,\
                   21.65685424949238, 27.899494936611667, 21.72792206135786, 34.97056274847714, 18.89949493661167,\
                   30.899494936611667, 32.89949493661167, 22.414213562373096, 21.899494936611667, 32.97056274847714,\
                   28.384776310850242, 34.970562748477136, 26.82842712474619, 35.798989873223334, 30.142135623730955,\
                   28.62741699796953, 24.899494936611667, 25.970562748477146, 34.970562748477136, 35.79898987322333] 

    if (task is None) or not (0 <= task < 25):
        task = randint(0, 24)


    start = Node(*starts[task])
    goal = Node(*goals[task])
    cardLength = cardLengths[task]
    diagLength = diagLengths[task]
    try:
        result = SearchFunction(taskMap, start.i, start.j, goal.i, goal.j, *args)
        nodesExpanded = result[2]
        nodesOpened = result[3]
        if result[0]:
            path = MakePath(result[1])
            correct = (int(path[1])  == int(cardLength) or abs(float(path[1]) - float(diagLength)) < 1e-6)
            Draw(taskMap, start, goal, path[0], nodesExpanded, nodesOpened)
            print("Path found! Length: " + str(path[1]) + ". Nodes created: " + str(len(nodesOpened) + len(nodesExpanded)) + ". Number of steps: " + str(len(nodesExpanded)) + ". Correct: " + str(correct))
        else:
            print("Path not found!")

    except Exception as e:
        print("Execution error")
        print(e)

# %%
def MassiveTest(SearchFunction, *args):
    '''
    MassiveTest runs SearchFunction on set of differnt tasks (from directory Data/) with *args as optional arguments and for every task displays one of these short reports:
     - 'Path found!' and some statistics -- path was found
     - 'Path not found!' -- path was not found
     - 'Execution error' -- an error occurred while executing the SearchFunction In first two cases function also draws visualisation of the task.
    
    Massive test return a dictionary with statistics of path finding. Dictionary contains next fields:
     - "corr" -- the correctness of every path length (True/False)
     - "len" -- the length of every path (0.0 if path not found)
     - "nc" -- the number of created nodes for every task execution
     - "st" -- the number of steps of algorithm for every task execution
    '''
    
    stat = dict()
    stat["corr"] = []
    stat["len"] = []
    stat["nc"] = []
    stat["st"] = []
    taskNum = 9
    taskMap = Map()
    for taskCount in range(taskNum):
        taskFileName = "Data/" + str(taskCount) + ".map"
        width, height, cells, iStart, jStart, iGoal, jGoal, cardinalLength, diagonalLength = ReadTaskFromFile(taskFileName)
        taskMap.SetGridCells(width,height,cells)
        try:
            result = SearchFunction(taskMap, iStart, jStart, iGoal, jGoal, *args)
            nodesExpanded = result[2]
            nodesOpened = result[3]
            if result[0]:
                path = MakePath(result[1]) 
                stat["len"].append(path[1])
                correct = (int(path[1])  == int(cardinalLength) or abs(float(path[1]) - float(diagonalLength)) < 1e-6)
                stat["corr"].append(correct)
                Draw(taskMap, Node(iStart, jStart), Node(iGoal, jGoal), path[0], nodesExpanded, nodesOpened)
                print("Path found! Length: " + str(path[1]) + ". Nodes created: " + str(len(nodesOpened) + len(nodesExpanded)) + ". Number of steps: " + str(len(nodesExpanded)) + ". Correct: " + str(correct))
            else:
                print("Path not found!")
                stat["corr"].append(False)
                stat["len"].append(0.0)

            stat["nc"].append(len(nodesOpened) + len(nodesExpanded))
            stat["st"].append(len(nodesExpanded))

        except Exception as e:
            print("Execution error")
            print(e)

    return stat

# %% [markdown]
# ## Dijkstra algorithm
#
# The input is:
# - map
# - start/goal
# - heuristic function (None by defalut)
# - the references to the implementation of OPEN and CLOSED (defaults are provided)
#
# Please note, that technically there is no need to pass heuristic function to Dijkstra's algorithm. However to unify it with A* we keep this parameter as a take-in argument.
#
# The output is:
# - path found flag (`true` or `false`)
# - last node of the path (so one can unwind it using the parent-pointers further on)
# - OPEN and CLOSED nodes for further visualization purposes

# %%
def Dijkstra(gridMap : Map, iStart : int, jStart : int, iGoal : int, jGoal : int, heuristicFunction = None, openType = OpenList, closedType = ClosedList, diagonalMoves = False):

    OPEN = openType()
    CLOSED = closedType()
    
    start = Node(iStart, jStart)
    OPEN.AddNode(start)
    
    while not OPEN.isEmpty():
      curNode = OPEN.GetBestNode()
      CLOSED.AddNode(curNode)

      if curNode.i == iGoal and curNode.j == jGoal:
        return True, curNode, CLOSED, OPEN 

      neighbors = gridMap.GetNeighbors(curNode.i, curNode.j, diagonalMoves)
      for n in neighbors:
        newNode = Node(n[0], n[1])
        newNode.g = curNode.g + ComputeCost(curNode.i, curNode.j, newNode.i, newNode.j)
        newNode.h = 0
        newNode.F = newNode.g
        newNode.parent = curNode

        if CLOSED.WasExpanded(newNode):
          continue
        OPEN.AddNode(newNode)


    return (False, None, CLOSED, OPEN)

# %% [markdown]
# Now let's test the implementation.

# %%
#This should work correct (but somewhat slow) in case your implementatation of Dijkstra is correct
for j in range(25):
  # %time SimpleTest(Dijkstra, j, None, OpenList, ClosedList,False)
# Out:
# Path found! Length: 36. Nodes created: 284. Number of steps: 276. Correct: True
# CPU times: user 45.7 ms, sys: 780 µs, total: 46.5 ms
# Wall time: 52.7 ms
# Path found! Length: 30. Nodes created: 221. Number of steps: 212. Correct: True
# CPU times: user 31.1 ms, sys: 0 ns, total: 31.1 ms
# Wall time: 31.1 ms
# Path found! Length: 30. Nodes created: 311. Number of steps: 300. Correct: True
# CPU times: user 44.6 ms, sys: 2.45 ms, total: 47.1 ms
# Wall time: 47.2 ms
# Path found! Length: 21. Nodes created: 181. Number of steps: 175. Correct: True
# CPU times: user 25.8 ms, sys: 0 ns, total: 25.8 ms
# Wall time: 25.9 ms
# Path found! Length: 28. Nodes created: 266. Number of steps: 258. Correct: True
# CPU times: user 38.8 ms, sys: 0 ns, total: 38.8 ms
# Wall time: 38.7 ms
# Path found! Length: 24. Nodes created: 366. Number of steps: 354. Correct: True
# CPU times: user 66.1 ms, sys: 511 µs, total: 66.6 ms
# Wall time: 68.1 ms
# Path found! Length: 32. Nodes created: 370. Number of steps: 358. Correct: True
# CPU times: user 59.6 ms, sys: 2.59 ms, total: 62.2 ms
# Wall time: 61.4 ms
# Path found! Length: 27. Nodes created: 368. Number of steps: 363. Correct: True
# CPU times: user 56.8 ms, sys: 1.63 ms, total: 58.5 ms
# Wall time: 58.6 ms
# Path found! Length: 42. Nodes created: 358. Number of steps: 346. Correct: True
# CPU times: user 56.1 ms, sys: 0 ns, total: 56.1 ms
# Wall time: 56.2 ms
# Path found! Length: 23. Nodes created: 229. Number of steps: 223. Correct: True
# CPU times: user 37.4 ms, sys: 512 µs, total: 37.9 ms
# Wall time: 38.3 ms
# Path found! Length: 35. Nodes created: 372. Number of steps: 360. Correct: True
# CPU times: user 62.5 ms, sys: 1.75 ms, total: 64.3 ms
# Wall time: 63.6 ms
# Path found! Length: 37. Nodes created: 380. Number of steps: 371. Correct: True
# CPU times: user 61.7 ms, sys: 1.59 ms, total: 63.3 ms
# Wall time: 62.8 ms
# Path found! Length: 23. Nodes created: 369. Number of steps: 364. Correct: True
# CPU times: user 61.9 ms, sys: 0 ns, total: 61.9 ms
# Wall time: 61.4 ms
# Path found! Length: 26. Nodes created: 279. Number of steps: 269. Correct: True
# CPU times: user 45.4 ms, sys: 0 ns, total: 45.4 ms
# Wall time: 44.9 ms
# Path found! Length: 40. Nodes created: 387. Number of steps: 382. Correct: True
# CPU times: user 77.2 ms, sys: 5.64 ms, total: 82.9 ms
# Wall time: 82.5 ms
# Path found! Length: 36. Nodes created: 390. Number of steps: 388. Correct: True
# CPU times: user 76.5 ms, sys: 875 µs, total: 77.4 ms
# Wall time: 81 ms
# Path found! Length: 42. Nodes created: 375. Number of steps: 365. Correct: True
# CPU times: user 69.2 ms, sys: 3.78 ms, total: 73 ms
# Wall time: 73 ms
# Path found! Length: 28. Nodes created: 279. Number of steps: 271. Correct: True
# CPU times: user 43.9 ms, sys: 939 µs, total: 44.9 ms
# Wall time: 44.1 ms
# Path found! Length: 44. Nodes created: 390. Number of steps: 389. Correct: True
# CPU times: user 67.8 ms, sys: 0 ns, total: 67.8 ms
# Wall time: 67.4 ms
# Path found! Length: 36. Nodes created: 377. Number of steps: 367. Correct: True
# CPU times: user 63.1 ms, sys: 1.61 ms, total: 64.7 ms
# Wall time: 64.2 ms
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Path found! Length: 38. Nodes created: 372. Number of steps: 361. Correct: True
# CPU times: user 72.7 ms, sys: 610 µs, total: 73.3 ms
# Wall time: 75.3 ms
# Path found! Length: 29. Nodes created: 275. Number of steps: 267. Correct: True
# CPU times: user 45.9 ms, sys: 1.91 ms, total: 47.8 ms
# Wall time: 47.4 ms
# Path found! Length: 33. Nodes created: 374. Number of steps: 364. Correct: True
# CPU times: user 63 ms, sys: 846 µs, total: 63.9 ms
# Wall time: 63.2 ms
# Path found! Length: 42. Nodes created: 382. Number of steps: 374. Correct: True
# CPU times: user 65 ms, sys: 0 ns, total: 65 ms
# Wall time: 64.4 ms
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Path found! Length: 44. Nodes created: 388. Number of steps: 383. Correct: True
# CPU times: user 73.7 ms, sys: 2.77 ms, total: 76.5 ms
# Wall time: 75.2 ms

# %%
#This should work better (=faster) in case:
# i) your implementation of Dijkstra is correct
# ii) your implementation of OPEN/CLOSED is efficient
for j in range(25):
  # %time SimpleTest(Dijkstra, j, None, YourOpen, YourClosed, False)
# Out:
# Path found! Length: 36. Nodes created: 284. Number of steps: 276. Correct: True
# CPU times: user 23.9 ms, sys: 0 ns, total: 23.9 ms
# Wall time: 26.6 ms
# Path found! Length: 30. Nodes created: 221. Number of steps: 212. Correct: True
# CPU times: user 20.3 ms, sys: 1 ms, total: 21.4 ms
# Wall time: 20.4 ms
# Path found! Length: 30. Nodes created: 311. Number of steps: 300. Correct: True
# CPU times: user 20.8 ms, sys: 0 ns, total: 20.8 ms
# Wall time: 20.4 ms
# Path found! Length: 21. Nodes created: 181. Number of steps: 175. Correct: True
# CPU times: user 18.3 ms, sys: 2.05 ms, total: 20.3 ms
# Wall time: 19.2 ms
# Path found! Length: 28. Nodes created: 266. Number of steps: 258. Correct: True
# CPU times: user 22.6 ms, sys: 1.1 ms, total: 23.6 ms
# Wall time: 22.4 ms
# Path found! Length: 24. Nodes created: 366. Number of steps: 354. Correct: True
# CPU times: user 21.6 ms, sys: 0 ns, total: 21.6 ms
# Wall time: 21.1 ms
# Path found! Length: 32. Nodes created: 370. Number of steps: 358. Correct: True
# CPU times: user 21.6 ms, sys: 3.14 ms, total: 24.8 ms
# Wall time: 23.5 ms
# Path found! Length: 27. Nodes created: 368. Number of steps: 363. Correct: True
# CPU times: user 23.1 ms, sys: 0 ns, total: 23.1 ms
# Wall time: 22.6 ms
# Path found! Length: 42. Nodes created: 358. Number of steps: 346. Correct: True
# CPU times: user 21.9 ms, sys: 0 ns, total: 21.9 ms
# Wall time: 21.5 ms
# Path found! Length: 23. Nodes created: 229. Number of steps: 223. Correct: True
# CPU times: user 19.3 ms, sys: 918 µs, total: 20.2 ms
# Wall time: 19.3 ms
# Path found! Length: 35. Nodes created: 372. Number of steps: 360. Correct: True
# CPU times: user 25.7 ms, sys: 3 ms, total: 28.7 ms
# Wall time: 27.6 ms
# Path found! Length: 37. Nodes created: 380. Number of steps: 371. Correct: True
# CPU times: user 25 ms, sys: 1.04 ms, total: 26 ms
# Wall time: 24.8 ms
# Path found! Length: 23. Nodes created: 369. Number of steps: 364. Correct: True
# CPU times: user 22 ms, sys: 0 ns, total: 22 ms
# Wall time: 21.6 ms
# Path found! Length: 26. Nodes created: 279. Number of steps: 269. Correct: True
# CPU times: user 22.3 ms, sys: 0 ns, total: 22.3 ms
# Wall time: 21.4 ms
# Path found! Length: 40. Nodes created: 387. Number of steps: 382. Correct: True
# CPU times: user 24.8 ms, sys: 3.08 ms, total: 27.9 ms
# Wall time: 27.2 ms
# Path found! Length: 36. Nodes created: 390. Number of steps: 388. Correct: True
# CPU times: user 23.7 ms, sys: 0 ns, total: 23.7 ms
# Wall time: 23.3 ms
# Path found! Length: 42. Nodes created: 375. Number of steps: 365. Correct: True
# CPU times: user 22.5 ms, sys: 0 ns, total: 22.5 ms
# Wall time: 22.1 ms
# Path found! Length: 28. Nodes created: 279. Number of steps: 271. Correct: True
# CPU times: user 31.1 ms, sys: 77 µs, total: 31.1 ms
# Wall time: 29.7 ms
# Path found! Length: 44. Nodes created: 390. Number of steps: 389. Correct: True
# CPU times: user 30.3 ms, sys: 1.09 ms, total: 31.4 ms
# Wall time: 30.4 ms
# Path found! Length: 36. Nodes created: 377. Number of steps: 367. Correct: True
# CPU times: user 23.4 ms, sys: 0 ns, total: 23.4 ms
# Wall time: 23.8 ms
# Path found! Length: 38. Nodes created: 372. Number of steps: 361. Correct: True
# CPU times: user 21.3 ms, sys: 0 ns, total: 21.3 ms
# Wall time: 21.4 ms
# Path found! Length: 29. Nodes created: 275. Number of steps: 267. Correct: True
# CPU times: user 19 ms, sys: 0 ns, total: 19 ms
# Wall time: 19 ms
# Path found! Length: 33. Nodes created: 374. Number of steps: 364. Correct: True
# CPU times: user 21.5 ms, sys: 0 ns, total: 21.5 ms
# Wall time: 21.5 ms
# Path found! Length: 42. Nodes created: 382. Number of steps: 374. Correct: True
# CPU times: user 22.6 ms, sys: 0 ns, total: 22.6 ms
# Wall time: 22.6 ms
# Path found! Length: 44. Nodes created: 388. Number of steps: 383. Correct: True
# CPU times: user 20.8 ms, sys: 685 µs, total: 21.5 ms
# Wall time: 21.6 ms
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
# %time SimpleTest(Dijkstra, 0, None, YourOpen, YourClosed, True)
# Out:
# Path found! Length: 36. Nodes created: 284. Number of steps: 276. Correct: True
# CPU times: user 26.9 ms, sys: 978 µs, total: 27.9 ms
# Wall time: 30.7 ms

# %%
#Running Dijkstra with the default (list-based) implementation of OPEN/CLOSED will take looooots of time.
#So try running it with your (efficient) implementation of Open/Closed
# %time dijkStat = MassiveTest(Dijkstra, None, YourOpen, YourClosed, False)
# Out:
# Path found! Length: 64. Nodes created: 1782. Number of steps: 1758. Correct: True
# Path found! Length: 197. Nodes created: 7452. Number of steps: 7449. Correct: True
# Path found! Length: 462. Nodes created: 45903. Number of steps: 45896. Correct: True
# Path found! Length: 498. Nodes created: 44455. Number of steps: 44439. Correct: True
# Path found! Length: 479. Nodes created: 47540. Number of steps: 47536. Correct: True
# Path found! Length: 402. Nodes created: 28175. Number of steps: 28173. Correct: True
# Path found! Length: 721. Nodes created: 112530. Number of steps: 112463. Correct: True
# Path found! Length: 678. Nodes created: 77449. Number of steps: 77396. Correct: True
# Path found! Length: 683. Nodes created: 95875. Number of steps: 95850. Correct: True
# CPU times: user 12.7 s, sys: 155 ms, total: 12.8 s
# Wall time: 15.2 s

# %%
#running massive test of Dijkstra algorithm on 8-connected grids
# %time dijkDiagStat = MassiveTest(Dijkstra, None, YourOpen, YourClosed, True)
# Out:
# Path found! Length: 64. Nodes created: 1782. Number of steps: 1758. Correct: True
# Path found! Length: 197. Nodes created: 7452. Number of steps: 7449. Correct: True
# Path found! Length: 462. Nodes created: 45903. Number of steps: 45896. Correct: True
# Path found! Length: 498. Nodes created: 44455. Number of steps: 44439. Correct: True
# Path found! Length: 479. Nodes created: 47540. Number of steps: 47536. Correct: True
# Path found! Length: 402. Nodes created: 28175. Number of steps: 28173. Correct: True
# Path found! Length: 721. Nodes created: 112530. Number of steps: 112463. Correct: True
# Path found! Length: 678. Nodes created: 77449. Number of steps: 77396. Correct: True
# Path found! Length: 683. Nodes created: 95875. Number of steps: 95850. Correct: True
# CPU times: user 21.2 s, sys: 106 ms, total: 21.3 s
# Wall time: 21.4 s

# %% [markdown]
# ## A* algorithm

# %%
def DiagonalDistance(i1, j1, i2, j2):
    return math.sqrt(abs(abs(j1 - j2) - abs(i1 - i2)) + math.sqrt(2)*min(abs(j1 - j2),abs(i1 - i2) ) )

# %%
def ManhattanDistance(i1, j1, i2, j2):
    return (abs(i1 - i2) + abs(j1 - j2))

# %%
def EuclideanDistance(i1, j1, i2, j2):
    return math.sqrt((i1 - i2)**2 + (j1 - j2)**2)

# %%
 def AStar(gridMap : Map, iStart : int, jStart : int, iGoal : int, jGoal : int, heuristicFunction = ManhattanDistance, openType = OpenList, closedType = ClosedList, diagonalMoves = False):

    OPEN = openType()
    CLOSED = closedType()
    
    start = Node(iStart, jStart)
    OPEN.AddNode(start)
    
    while not OPEN.isEmpty():
      curNode = OPEN.GetBestNode()
      CLOSED.AddNode(curNode)

      if curNode.i == iGoal and curNode.j == jGoal:
        return True, curNode, CLOSED, OPEN 

      neighbors = gridMap.GetNeighbors(curNode.i, curNode.j, diagonalMoves)
      for n in neighbors:
        newNode = Node(n[0], n[1])
        newNode.g = curNode.g + ComputeCost(curNode.i, curNode.j, newNode.i, newNode.j)
        newNode.h = heuristicFunction(curNode.i, curNode.j, iGoal, jGoal)
        newNode.F = newNode.g + newNode.h
        newNode.parent = curNode

        if CLOSED.WasExpanded(newNode):
          continue
        OPEN.AddNode(newNode)
    return (False, None, CLOSED, OPEN)

# %%
for i in range(25):
  # %time SimpleTest(AStar, i, ManhattanDistance, OpenList, ClosedList, True )
# Out:
# Path found! Length: 36. Nodes created: 272. Number of steps: 242. Correct: True
# CPU times: user 67.1 ms, sys: 0 ns, total: 67.1 ms
# Wall time: 77.7 ms
# Path found! Length: 30. Nodes created: 215. Number of steps: 189. Correct: True
# CPU times: user 44.4 ms, sys: 0 ns, total: 44.4 ms
# Wall time: 44.5 ms
# Path found! Length: 30. Nodes created: 208. Number of steps: 162. Correct: True
# CPU times: user 37.3 ms, sys: 0 ns, total: 37.3 ms
# Wall time: 37.4 ms
# Path found! Length: 21. Nodes created: 153. Number of steps: 134. Correct: True
# CPU times: user 30.3 ms, sys: 0 ns, total: 30.3 ms
# Wall time: 30.5 ms
# Path found! Length: 28. Nodes created: 223. Number of steps: 183. Correct: True
# CPU times: user 46.5 ms, sys: 0 ns, total: 46.5 ms
# Wall time: 46.6 ms
# Path found! Length: 24. Nodes created: 159. Number of steps: 137. Correct: True
# CPU times: user 31.2 ms, sys: 0 ns, total: 31.2 ms
# Wall time: 31.2 ms
# Path found! Length: 32. Nodes created: 245. Number of steps: 208. Correct: True
# CPU times: user 49.6 ms, sys: 1.95 ms, total: 51.5 ms
# Wall time: 53.2 ms
# Path found! Length: 27. Nodes created: 217. Number of steps: 185. Correct: True
# CPU times: user 45.4 ms, sys: 1 µs, total: 45.4 ms
# Wall time: 45 ms
# Path found! Length: 42. Nodes created: 294. Number of steps: 272. Correct: True
# CPU times: user 71.6 ms, sys: 1.01 ms, total: 72.6 ms
# Wall time: 73.2 ms
# Path found! Length: 23. Nodes created: 142. Number of steps: 118. Correct: True
# CPU times: user 30 ms, sys: 14 µs, total: 30 ms
# Wall time: 29.7 ms
# Path found! Length: 35. Nodes created: 272. Number of steps: 243. Correct: True
# CPU times: user 64.5 ms, sys: 1.01 ms, total: 65.6 ms
# Wall time: 65.2 ms
# Path found! Length: 37. Nodes created: 272. Number of steps: 238. Correct: True
# CPU times: user 70.1 ms, sys: 1.04 ms, total: 71.2 ms
# Wall time: 67.8 ms
# Path found! Length: 23. Nodes created: 192. Number of steps: 146. Correct: True
# CPU times: user 36.4 ms, sys: 993 µs, total: 37.4 ms
# Wall time: 37.2 ms
# Path found! Length: 26. Nodes created: 151. Number of steps: 124. Correct: True
# CPU times: user 30.4 ms, sys: 991 µs, total: 31.4 ms
# Wall time: 30.6 ms
# Path found! Length: 40. Nodes created: 354. Number of steps: 347. Correct: True
# CPU times: user 102 ms, sys: 8 µs, total: 102 ms
# Wall time: 102 ms
# Path found! Length: 36. Nodes created: 276. Number of steps: 253. Correct: True
# CPU times: user 63.5 ms, sys: 0 ns, total: 63.5 ms
# Wall time: 63.5 ms
# Path found! Length: 42. Nodes created: 297. Number of steps: 258. Correct: True
# CPU times: user 67.1 ms, sys: 0 ns, total: 67.1 ms
# Wall time: 66.5 ms
# Path found! Length: 28. Nodes created: 234. Number of steps: 204. Correct: True
# CPU times: user 50.6 ms, sys: 989 µs, total: 51.6 ms
# Wall time: 51.7 ms
# Path found! Length: 44. Nodes created: 316. Number of steps: 284. Correct: True
# CPU times: user 82.3 ms, sys: 984 µs, total: 83.3 ms
# Wall time: 86 ms
# Path found! Length: 36. Nodes created: 256. Number of steps: 217. Correct: True
# CPU times: user 56.7 ms, sys: 6 µs, total: 56.7 ms
# Wall time: 56.4 ms
# Path found! Length: 38. Nodes created: 284. Number of steps: 256. Correct: True
# CPU times: user 69.3 ms, sys: 0 ns, total: 69.3 ms
# Wall time: 68.6 ms
# Path found! Length: 29. Nodes created: 242. Number of steps: 200. Correct: True
# CPU times: user 58.3 ms, sys: 2.02 ms, total: 60.3 ms
# Wall time: 59.1 ms
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Path found! Length: 33. Nodes created: 272. Number of steps: 233. Correct: True
# CPU times: user 66.7 ms, sys: 10 µs, total: 66.7 ms
# Wall time: 69.6 ms
# Path found! Length: 42. Nodes created: 270. Number of steps: 240. Correct: True
# CPU times: user 66 ms, sys: 48 µs, total: 66.1 ms
# Wall time: 66.9 ms
# Path found! Length: 44. Nodes created: 308. Number of steps: 286. Correct: True
# CPU times: user 76.2 ms, sys: 983 µs, total: 77.2 ms
# Wall time: 77.8 ms
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
for i in range(25):
  # %time SimpleTest(AStar, i, ManhattanDistance, YourOpen, YourClosed)
# Out:
# Path found! Length: 36. Nodes created: 272. Number of steps: 242. Correct: True
# CPU times: user 23 ms, sys: 0 ns, total: 23 ms
# Wall time: 27.3 ms
# Path found! Length: 30. Nodes created: 215. Number of steps: 189. Correct: True
# CPU times: user 21 ms, sys: 0 ns, total: 21 ms
# Wall time: 21 ms
# Path found! Length: 30. Nodes created: 208. Number of steps: 162. Correct: True
# CPU times: user 19.4 ms, sys: 2 ms, total: 21.4 ms
# Wall time: 20.8 ms
# Path found! Length: 21. Nodes created: 153. Number of steps: 134. Correct: True
# CPU times: user 17.2 ms, sys: 3 µs, total: 17.2 ms
# Wall time: 17.2 ms
# Path found! Length: 28. Nodes created: 223. Number of steps: 183. Correct: True
# CPU times: user 18.5 ms, sys: 0 ns, total: 18.5 ms
# Wall time: 18.5 ms
# Path found! Length: 24. Nodes created: 159. Number of steps: 137. Correct: True
# CPU times: user 16.5 ms, sys: 2 µs, total: 16.5 ms
# Wall time: 16.5 ms
# Path found! Length: 32. Nodes created: 245. Number of steps: 208. Correct: True
# CPU times: user 20.2 ms, sys: 1 µs, total: 20.2 ms
# Wall time: 19.7 ms
# Path found! Length: 27. Nodes created: 217. Number of steps: 185. Correct: True
# CPU times: user 21.2 ms, sys: 17 µs, total: 21.2 ms
# Wall time: 20.1 ms
# Path found! Length: 42. Nodes created: 294. Number of steps: 272. Correct: True
# CPU times: user 20.3 ms, sys: 6 µs, total: 20.3 ms
# Wall time: 19.9 ms
# Path found! Length: 23. Nodes created: 142. Number of steps: 118. Correct: True
# CPU times: user 16.9 ms, sys: 1 ms, total: 18 ms
# Wall time: 17 ms
# Path found! Length: 35. Nodes created: 272. Number of steps: 243. Correct: True
# CPU times: user 23 ms, sys: 1.02 ms, total: 24 ms
# Wall time: 23 ms
# Path found! Length: 37. Nodes created: 272. Number of steps: 238. Correct: True
# CPU times: user 20.9 ms, sys: 983 µs, total: 21.9 ms
# Wall time: 21.4 ms
# Path found! Length: 23. Nodes created: 192. Number of steps: 146. Correct: True
# CPU times: user 20 ms, sys: 17 µs, total: 20 ms
# Wall time: 18.9 ms
# Path found! Length: 26. Nodes created: 151. Number of steps: 124. Correct: True
# CPU times: user 19.1 ms, sys: 198 µs, total: 19.3 ms
# Wall time: 18.2 ms
# Path found! Length: 40. Nodes created: 354. Number of steps: 347. Correct: True
# CPU times: user 23.8 ms, sys: 0 ns, total: 23.8 ms
# Wall time: 23.6 ms
# Path found! Length: 36. Nodes created: 276. Number of steps: 253. Correct: True
# CPU times: user 23.2 ms, sys: 1e+03 ns, total: 23.2 ms
# Wall time: 22.9 ms
# Path found! Length: 42. Nodes created: 297. Number of steps: 258. Correct: True
# CPU times: user 24 ms, sys: 23 µs, total: 24 ms
# Wall time: 22.4 ms
# Path found! Length: 28. Nodes created: 234. Number of steps: 204. Correct: True
# CPU times: user 19.8 ms, sys: 10 µs, total: 19.8 ms
# Wall time: 19.3 ms
# Path found! Length: 44. Nodes created: 316. Number of steps: 284. Correct: True
# CPU times: user 20.2 ms, sys: 2.01 ms, total: 22.2 ms
# Wall time: 21.9 ms
# Path found! Length: 36. Nodes created: 256. Number of steps: 217. Correct: True
# CPU times: user 18.3 ms, sys: 973 µs, total: 19.3 ms
# Wall time: 19.1 ms
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Path found! Length: 38. Nodes created: 284. Number of steps: 256. Correct: True
# CPU times: user 24.9 ms, sys: 2.02 ms, total: 27 ms
# Wall time: 26.3 ms
# Path found! Length: 29. Nodes created: 242. Number of steps: 200. Correct: True
# CPU times: user 32.8 ms, sys: 4.01 ms, total: 36.8 ms
# Wall time: 35.4 ms
# Path found! Length: 33. Nodes created: 272. Number of steps: 233. Correct: True
# CPU times: user 19.7 ms, sys: 852 µs, total: 20.5 ms
# Wall time: 20.6 ms
# Path found! Length: 42. Nodes created: 270. Number of steps: 240. Correct: True
# CPU times: user 21.4 ms, sys: 0 ns, total: 21.4 ms
# Wall time: 21.7 ms
# Path found! Length: 44. Nodes created: 308. Number of steps: 286. Correct: True
# CPU times: user 19.2 ms, sys: 0 ns, total: 19.2 ms
# Wall time: 19.3 ms

# %%
for i in range(25):
  # %time SimpleTest(AStar, i, ManhattanDistance, YourOpen, YourClosed)
# Out:
# Path found! Length: 36. Nodes created: 272. Number of steps: 242. Correct: True
# CPU times: user 22.7 ms, sys: 0 ns, total: 22.7 ms
# Wall time: 23.6 ms
# Path found! Length: 30. Nodes created: 215. Number of steps: 189. Correct: True
# CPU times: user 17.4 ms, sys: 1 µs, total: 17.4 ms
# Wall time: 17.5 ms
# Path found! Length: 30. Nodes created: 208. Number of steps: 162. Correct: True
# CPU times: user 18.7 ms, sys: 1.02 ms, total: 19.7 ms
# Wall time: 19.1 ms
# Path found! Length: 21. Nodes created: 153. Number of steps: 134. Correct: True
# CPU times: user 19 ms, sys: 0 ns, total: 19 ms
# Wall time: 18.9 ms
# Path found! Length: 28. Nodes created: 223. Number of steps: 183. Correct: True
# CPU times: user 19.7 ms, sys: 6 µs, total: 19.7 ms
# Wall time: 19.3 ms
# Path found! Length: 24. Nodes created: 159. Number of steps: 137. Correct: True
# CPU times: user 16 ms, sys: 5.16 ms, total: 21.2 ms
# Wall time: 19.9 ms
# Path found! Length: 32. Nodes created: 245. Number of steps: 208. Correct: True
# CPU times: user 21.3 ms, sys: 19 µs, total: 21.3 ms
# Wall time: 20.1 ms
# Path found! Length: 27. Nodes created: 217. Number of steps: 185. Correct: True
# CPU times: user 18.2 ms, sys: 4.02 ms, total: 22.2 ms
# Wall time: 20.6 ms
# Path found! Length: 42. Nodes created: 294. Number of steps: 272. Correct: True
# CPU times: user 21.5 ms, sys: 4 µs, total: 21.5 ms
# Wall time: 21.1 ms
# Path found! Length: 23. Nodes created: 142. Number of steps: 118. Correct: True
# CPU times: user 19.1 ms, sys: 15 µs, total: 19.1 ms
# Wall time: 18 ms
# Path found! Length: 35. Nodes created: 272. Number of steps: 243. Correct: True
# CPU times: user 25 ms, sys: 1.02 ms, total: 26 ms
# Wall time: 26.2 ms
# Path found! Length: 37. Nodes created: 272. Number of steps: 238. Correct: True
# CPU times: user 22.9 ms, sys: 1 ms, total: 23.9 ms
# Wall time: 22.8 ms
# Path found! Length: 23. Nodes created: 192. Number of steps: 146. Correct: True
# CPU times: user 20.6 ms, sys: 1.03 ms, total: 21.7 ms
# Wall time: 20.4 ms
# Path found! Length: 26. Nodes created: 151. Number of steps: 124. Correct: True
# CPU times: user 16.3 ms, sys: 1.17 ms, total: 17.5 ms
# Wall time: 17.1 ms
# Path found! Length: 40. Nodes created: 354. Number of steps: 347. Correct: True
# CPU times: user 21.9 ms, sys: 0 ns, total: 21.9 ms
# Wall time: 21.5 ms
# Path found! Length: 36. Nodes created: 276. Number of steps: 253. Correct: True
# CPU times: user 28.1 ms, sys: 44 µs, total: 28.1 ms
# Wall time: 26.7 ms
# Path found! Length: 42. Nodes created: 297. Number of steps: 258. Correct: True
# CPU times: user 25.2 ms, sys: 17 µs, total: 25.2 ms
# Wall time: 24.4 ms
# Path found! Length: 28. Nodes created: 234. Number of steps: 204. Correct: True
# CPU times: user 22.3 ms, sys: 19 µs, total: 22.3 ms
# Wall time: 21 ms
# Path found! Length: 44. Nodes created: 316. Number of steps: 284. Correct: True
# CPU times: user 21.4 ms, sys: 5 µs, total: 21.4 ms
# Wall time: 20.9 ms
# Path found! Length: 36. Nodes created: 256. Number of steps: 217. Correct: True
# CPU times: user 21.7 ms, sys: 28 µs, total: 21.8 ms
# Wall time: 20.6 ms
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Path found! Length: 38. Nodes created: 284. Number of steps: 256. Correct: True
# CPU times: user 26.8 ms, sys: 28 µs, total: 26.9 ms
# Wall time: 26.9 ms
# Path found! Length: 29. Nodes created: 242. Number of steps: 200. Correct: True
# CPU times: user 23 ms, sys: 1.02 ms, total: 24 ms
# Wall time: 23.5 ms
# Path found! Length: 33. Nodes created: 272. Number of steps: 233. Correct: True
# CPU times: user 20.7 ms, sys: 153 µs, total: 20.9 ms
# Wall time: 20.4 ms
# Path found! Length: 42. Nodes created: 270. Number of steps: 240. Correct: True
# CPU times: user 21 ms, sys: 0 ns, total: 21 ms
# Wall time: 20.7 ms
# Path found! Length: 44. Nodes created: 308. Number of steps: 286. Correct: True
# CPU times: user 24.7 ms, sys: 24 µs, total: 24.7 ms
# Wall time: 23.4 ms

# %%
for i in range(25):
  # %time SimpleTest(AStar, i, DiagonalDistance, YourOpen, YourClosed, False)
# Out:
# Path found! Length: 36. Nodes created: 280. Number of steps: 271. Correct: True
# CPU times: user 27 ms, sys: 0 ns, total: 27 ms
# Wall time: 27.9 ms
# Path found! Length: 30. Nodes created: 219. Number of steps: 210. Correct: True
# CPU times: user 20.1 ms, sys: 0 ns, total: 20.1 ms
# Wall time: 20.4 ms
# Path found! Length: 30. Nodes created: 297. Number of steps: 285. Correct: True
# CPU times: user 20.8 ms, sys: 0 ns, total: 20.8 ms
# Wall time: 20.9 ms
# Path found! Length: 21. Nodes created: 178. Number of steps: 171. Correct: True
# CPU times: user 19.5 ms, sys: 6 µs, total: 19.5 ms
# Wall time: 19.5 ms
# Path found! Length: 28. Nodes created: 263. Number of steps: 255. Correct: True
# CPU times: user 19.4 ms, sys: 0 ns, total: 19.4 ms
# Wall time: 19.4 ms
# Path found! Length: 24. Nodes created: 307. Number of steps: 288. Correct: True
# CPU times: user 22 ms, sys: 3 µs, total: 22 ms
# Wall time: 21.5 ms
# Path found! Length: 32. Nodes created: 357. Number of steps: 341. Correct: True
# CPU times: user 25.2 ms, sys: 15 µs, total: 25.2 ms
# Wall time: 23.9 ms
# Path found! Length: 27. Nodes created: 360. Number of steps: 352. Correct: True
# CPU times: user 22.8 ms, sys: 0 ns, total: 22.8 ms
# Wall time: 22.9 ms
# Path found! Length: 42. Nodes created: 346. Number of steps: 330. Correct: True
# CPU times: user 23.2 ms, sys: 2.02 ms, total: 25.2 ms
# Wall time: 24.1 ms
# Path found! Length: 23. Nodes created: 229. Number of steps: 223. Correct: True
# CPU times: user 24.6 ms, sys: 27 µs, total: 24.6 ms
# Wall time: 23 ms
# Path found! Length: 35. Nodes created: 357. Number of steps: 343. Correct: True
# CPU times: user 25.6 ms, sys: 0 ns, total: 25.6 ms
# Wall time: 25 ms
# Path found! Length: 37. Nodes created: 365. Number of steps: 352. Correct: True
# CPU times: user 25.4 ms, sys: 0 ns, total: 25.4 ms
# Wall time: 25.1 ms
# Path found! Length: 23. Nodes created: 341. Number of steps: 324. Correct: True
# CPU times: user 23.7 ms, sys: 0 ns, total: 23.7 ms
# Wall time: 23.3 ms
# Path found! Length: 26. Nodes created: 270. Number of steps: 260. Correct: True
# CPU times: user 31.3 ms, sys: 972 µs, total: 32.2 ms
# Wall time: 29.8 ms
# Path found! Length: 40. Nodes created: 378. Number of steps: 370. Correct: True
# CPU times: user 22.1 ms, sys: 0 ns, total: 22.1 ms
# Wall time: 22.1 ms
# Path found! Length: 36. Nodes created: 384. Number of steps: 378. Correct: True
# CPU times: user 26.3 ms, sys: 0 ns, total: 26.3 ms
# Wall time: 27.4 ms
# Path found! Length: 42. Nodes created: 367. Number of steps: 354. Correct: True
# CPU times: user 22.6 ms, sys: 982 µs, total: 23.6 ms
# Wall time: 23.1 ms
# Path found! Length: 28. Nodes created: 266. Number of steps: 259. Correct: True
# CPU times: user 24.5 ms, sys: 22 µs, total: 24.5 ms
# Wall time: 26.3 ms
# Path found! Length: 44. Nodes created: 389. Number of steps: 387. Correct: True
# CPU times: user 27.3 ms, sys: 1 ms, total: 28.3 ms
# Wall time: 27.4 ms
# Path found! Length: 36. Nodes created: 366. Number of steps: 352. Correct: True
# CPU times: user 31.5 ms, sys: 106 µs, total: 31.6 ms
# Wall time: 31.6 ms
# Path found! Length: 38. Nodes created: 350. Number of steps: 339. Correct: True
# CPU times: user 28.1 ms, sys: 0 ns, total: 28.1 ms
# Wall time: 26.6 ms
# Path found! Length: 29. Nodes created: 270. Number of steps: 262. Correct: True
# CPU times: user 24 ms, sys: 2.04 ms, total: 26.1 ms
# Wall time: 24.4 ms
# Path found! Length: 33. Nodes created: 362. Number of steps: 353. Correct: True
# CPU times: user 25.7 ms, sys: 1.01 ms, total: 26.7 ms
# Wall time: 25.5 ms
# Path found! Length: 42. Nodes created: 376. Number of steps: 365. Correct: True
# CPU times: user 27.9 ms, sys: 14 µs, total: 27.9 ms
# Wall time: 26.7 ms
# Path found! Length: 44. Nodes created: 383. Number of steps: 375. Correct: True
# CPU times: user 24.1 ms, sys: 1.02 ms, total: 25.1 ms
# Wall time: 24.4 ms
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
for i in range(25):
  # %time SimpleTest(AStar, i, EuclideanDistance, YourOpen, YourClosed, True)
# Out:
# Path found! Length: 36. Nodes created: 273. Number of steps: 260. Correct: True
# CPU times: user 36.9 ms, sys: 0 ns, total: 36.9 ms
# Wall time: 39.2 ms
# Path found! Length: 30. Nodes created: 213. Number of steps: 186. Correct: True
# CPU times: user 24 ms, sys: 0 ns, total: 24 ms
# Wall time: 24.1 ms
# Path found! Length: 30. Nodes created: 265. Number of steps: 224. Correct: True
# CPU times: user 23.9 ms, sys: 970 µs, total: 24.9 ms
# Wall time: 24.9 ms
# Path found! Length: 21. Nodes created: 146. Number of steps: 129. Correct: True
# CPU times: user 20.3 ms, sys: 0 ns, total: 20.3 ms
# Wall time: 20.3 ms
# Path found! Length: 28. Nodes created: 257. Number of steps: 233. Correct: True
# CPU times: user 25.6 ms, sys: 0 ns, total: 25.6 ms
# Wall time: 25.8 ms
# Path found! Length: 24. Nodes created: 168. Number of steps: 148. Correct: True
# CPU times: user 19.8 ms, sys: 0 ns, total: 19.8 ms
# Wall time: 19.8 ms
# Path found! Length: 32. Nodes created: 280. Number of steps: 248. Correct: True
# CPU times: user 24.3 ms, sys: 0 ns, total: 24.3 ms
# Wall time: 24.3 ms
# Path found! Length: 27. Nodes created: 243. Number of steps: 221. Correct: True
# CPU times: user 25 ms, sys: 0 ns, total: 25 ms
# Wall time: 24.9 ms
# Path found! Length: 42. Nodes created: 306. Number of steps: 284. Correct: True
# CPU times: user 33.9 ms, sys: 25 µs, total: 33.9 ms
# Wall time: 32.7 ms
# Path found! Length: 23. Nodes created: 177. Number of steps: 156. Correct: True
# CPU times: user 23 ms, sys: 0 ns, total: 23 ms
# Wall time: 23.1 ms
# Path found! Length: 35. Nodes created: 311. Number of steps: 280. Correct: True
# CPU times: user 26.2 ms, sys: 0 ns, total: 26.2 ms
# Wall time: 26.2 ms
# Path found! Length: 37. Nodes created: 326. Number of steps: 301. Correct: True
# CPU times: user 30.4 ms, sys: 4 µs, total: 30.4 ms
# Wall time: 30.3 ms
# Path found! Length: 23. Nodes created: 207. Number of steps: 177. Correct: True
# CPU times: user 25.9 ms, sys: 14 µs, total: 25.9 ms
# Wall time: 25.1 ms
# Path found! Length: 26. Nodes created: 181. Number of steps: 157. Correct: True
# CPU times: user 22.4 ms, sys: 3 µs, total: 22.4 ms
# Wall time: 22.2 ms
# Path found! Length: 40. Nodes created: 355. Number of steps: 349. Correct: True
# CPU times: user 31.3 ms, sys: 0 ns, total: 31.3 ms
# Wall time: 30.7 ms
# Path found! Length: 36. Nodes created: 305. Number of steps: 295. Correct: True
# CPU times: user 29.5 ms, sys: 1.01 ms, total: 30.5 ms
# Wall time: 29.8 ms
# Path found! Length: 42. Nodes created: 316. Number of steps: 287. Correct: True
# CPU times: user 34.5 ms, sys: 21 µs, total: 34.5 ms
# Wall time: 34.1 ms
# Path found! Length: 28. Nodes created: 234. Number of steps: 218. Correct: True
# CPU times: user 23.2 ms, sys: 0 ns, total: 23.2 ms
# Wall time: 23.2 ms
# Path found! Length: 44. Nodes created: 360. Number of steps: 344. Correct: True
# CPU times: user 29.3 ms, sys: 0 ns, total: 29.3 ms
# Wall time: 29.3 ms
# Path found! Length: 36. Nodes created: 292. Number of steps: 256. Correct: True
# CPU times: user 26.5 ms, sys: 0 ns, total: 26.5 ms
# Wall time: 26.6 ms
# Path found! Length: 38. Nodes created: 319. Number of steps: 304. Correct: True
# CPU times: user 36.7 ms, sys: 0 ns, total: 36.7 ms
# Wall time: 36.7 ms
# Path found! Length: 29. Nodes created: 240. Number of steps: 217. Correct: True
# CPU times: user 24.8 ms, sys: 0 ns, total: 24.8 ms
# Wall time: 24.8 ms
# Path found! Length: 33. Nodes created: 297. Number of steps: 271. Correct: True
# CPU times: user 26.3 ms, sys: 0 ns, total: 26.3 ms
# Wall time: 26.3 ms
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Path found! Length: 42. Nodes created: 315. Number of steps: 286. Correct: True
# CPU times: user 29.7 ms, sys: 0 ns, total: 29.7 ms
# Wall time: 32.6 ms
# Path found! Length: 44. Nodes created: 333. Number of steps: 312. Correct: True
# CPU times: user 27.2 ms, sys: 0 ns, total: 27.2 ms
# Wall time: 27.2 ms

# %%
#running massive test of A* on 4-connected grids with Manhattan-distance heuristic
# %time astStat = MassiveTest(AStar, ManhattanDistance, YourOpen, YourClosed, False)
# Out:
# Path found! Length: 64. Nodes created: 1218. Number of steps: 1115. Correct: True
# Path found! Length: 197. Nodes created: 3987. Number of steps: 3854. Correct: True
# Path found! Length: 462. Nodes created: 22908. Number of steps: 22093. Correct: True
# Path found! Length: 498. Nodes created: 27941. Number of steps: 27641. Correct: True
# Path found! Length: 479. Nodes created: 25607. Number of steps: 24937. Correct: True
# Path found! Length: 402. Nodes created: 12005. Number of steps: 11554. Correct: True
# Path found! Length: 721. Nodes created: 76018. Number of steps: 75532. Correct: True
# Path found! Length: 678. Nodes created: 51224. Number of steps: 50311. Correct: True
# Path found! Length: 683. Nodes created: 55237. Number of steps: 53989. Correct: True
# CPU times: user 8.94 s, sys: 49.7 ms, total: 8.99 s
# Wall time: 9 s

# %%
#running massive test of A* on 8-connected grids with Manhattan-distance heuristic
# %time astManhStat = MassiveTest(AStar, ManhattanDistance, YourOpen, YourClosed, True)
# Out:
# Path found! Length: 64. Nodes created: 1218. Number of steps: 1115. Correct: True
# Path found! Length: 197. Nodes created: 3987. Number of steps: 3854. Correct: True
# Path found! Length: 462. Nodes created: 22908. Number of steps: 22093. Correct: True
# Path found! Length: 498. Nodes created: 27941. Number of steps: 27641. Correct: True
# Path found! Length: 479. Nodes created: 25607. Number of steps: 24937. Correct: True
# Path found! Length: 402. Nodes created: 12005. Number of steps: 11554. Correct: True
# Path found! Length: 721. Nodes created: 76018. Number of steps: 75532. Correct: True
# Path found! Length: 678. Nodes created: 51224. Number of steps: 50311. Correct: True
# Path found! Length: 683. Nodes created: 55237. Number of steps: 53989. Correct: True
# CPU times: user 14.5 s, sys: 58.4 ms, total: 14.6 s
# Wall time: 14.6 s

# %%
#running massive test of A* on 8-connected grids with Euclidean-distance heuristic
# %time astEuclidStat = MassiveTest(AStar, EuclideanDistance, YourOpen, YourClosed, True)
# Out:
# Path found! Length: 64. Nodes created: 1218. Number of steps: 1149. Correct: True
# Path found! Length: 197. Nodes created: 5381. Number of steps: 5243. Correct: True
# Path found! Length: 462. Nodes created: 38637. Number of steps: 38235. Correct: True
# Path found! Length: 498. Nodes created: 33059. Number of steps: 32768. Correct: True
# Path found! Length: 479. Nodes created: 42946. Number of steps: 42531. Correct: True
# Path found! Length: 402. Nodes created: 21500. Number of steps: 21304. Correct: True
# Path found! Length: 721. Nodes created: 87540. Number of steps: 87153. Correct: True
# Path found! Length: 678. Nodes created: 64486. Number of steps: 63972. Correct: True
# Path found! Length: 683. Nodes created: 77186. Number of steps: 76582. Correct: True
# CPU times: user 22.8 s, sys: 101 ms, total: 22.9 s
# Wall time: 23 s

# %%
#running massive test of A* on 8-connected grids with Diagonal-distance heuristic
# %time astDiagStat = MassiveTest(AStar, DiagonalDistance, YourOpen, YourClosed, True)
# Out:
# Path found! Length: 64. Nodes created: 1738. Number of steps: 1709. Correct: True
# Path found! Length: 197. Nodes created: 7429. Number of steps: 7417. Correct: True
# Path found! Length: 462. Nodes created: 45891. Number of steps: 45879. Correct: True
# Path found! Length: 498. Nodes created: 44425. Number of steps: 44405. Correct: True
# Path found! Length: 479. Nodes created: 47532. Number of steps: 47525. Correct: True
# Path found! Length: 402. Nodes created: 28172. Number of steps: 28167. Correct: True
# Path found! Length: 721. Nodes created: 111706. Number of steps: 111656. Correct: True
# Path found! Length: 678. Nodes created: 77266. Number of steps: 77213. Correct: True
# Path found! Length: 683. Nodes created: 95791. Number of steps: 95755. Correct: True
# CPU times: user 26.7 s, sys: 98.6 ms, total: 26.8 s
# Wall time: 26.8 s

# %% [markdown]
# # Analysis of results
# First of all lets compare Dijkstra and A* algorithms on 4-connected grids
#
# Secondly lets compare A* with different heuristics on 8-connected grids
#
# Additionally you can compare Dijkstra and A* algorithms on 8-connected grids or A* with different heuristics on 4-connected grids

# %% [markdown]
# ![2](./Image/3.png)

# %% [markdown]
# ## Part 1. Dijkstra vs A* on 4-connected grids

# %%
fig, axs = plt.subplots(3, 3, figsize=(15,10))
fig.suptitle('Average path length')
for i in range(9):
    ax = axs[i // 3, i % 3]
    ax.set_title(str(i) + " task")
    alg = ['A*', 'Dijkstra']
    lens = [astStat['len'][i], dijkStat['len'][i]]
    ax.bar(alg, lens)
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(15,10))
fig.suptitle('Average number of created nodes')
for i in range(9):
    ax = axs[i // 3, i % 3]
    ax.set_title(str(i) + " task")
    alg = ['A*', 'Dijkstra']
    ncs = [astStat['nc'][i], dijkStat['nc'][i]]
    ax.bar(alg, ncs)
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(15,10))
fig.suptitle('Average number of steps')
for i in range(9):
    ax = axs[i // 3, i % 3]
    ax.set_title(str(i) + " task")
    alg = ['A*', 'Dijkstra']
    sts = [astStat['st'][i], dijkStat['st'][i]]
    ax.bar(alg, sts)
plt.show()

# %% [markdown]
# ## Part 2. A* with different heuristics on 8-connected grids

# %%
fig, axs = plt.subplots(3, 3, figsize=(15,10))
fig.suptitle('Average path length')
for i in range(9):
    ax = axs[i // 3, i % 3]
    ax.set_title(str(i) + " task")
    alg = ['Manhattan', 'Euclidean', 'Diagonal']
    lens = [astManhStat['len'][i], astEuclidStat['len'][i], astDiagStat['len'][i]]
    ax.bar(alg, lens)
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(15,10))
fig.suptitle('Average number of created nodes')
for i in range(9):
    ax = axs[i // 3, i % 3]
    ax.set_title(str(i) + " task")
    alg = ['Manhattan', 'Euclidean', 'Diagonal']
    ncs = [astManhStat['nc'][i], astEuclidStat['nc'][i], astDiagStat['nc'][i]]
    ax.bar(alg, ncs)
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(15,10))
fig.suptitle('Average number of steps')
for i in range(9):
    ax = axs[i // 3, i % 3]
    ax.set_title(str(i) + " task")
    alg = ['Manhattan', 'Euclidean', 'Diagonal']
    ncs = [astManhStat['st'][i], astEuclidStat['st'][i], astDiagStat['st'][i]]
    ax.bar(alg, ncs)
plt.show()
