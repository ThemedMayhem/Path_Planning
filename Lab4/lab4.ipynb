# %% [markdown]
# # Anytime heuristic search

# %%
import copy
import math
from random import shuffle, randint
from heapq import heappop, heappush, heapify
import time

EPS = 0.00001

# %% [markdown]
# ## Grid Search Domain Representation

# %%
class Map:
    '''
    Square grid map class represents the environment for our moving agent
        - width -- the number of columns in the grid
        - height -- the number of rows in the grid
        - cells -- the binary matrix, that represents the grid. 0 - cell is traversable, 1 - cell is blocked
    '''

    def __init__(self):
        '''
        Default constructor
        '''

        self.width = 0
        self.height = 0
        self.cells = []
    

    def ReadFromString(self, cellStr, width, height):
        '''
        Converting a string (with '#' representing obstacles and '.' representing free cells) to a grid
        '''
        self.width = width
        self.height = height
        self.cells = [[0 for _ in range(width)] for _ in range(height)]
        cellLines = cellStr.split("\n")
        i = 0
        j = 0
        for l in cellLines:
            if len(l) != 0:
                j = 0
                for c in l:
                    if c == '.':
                        self.cells[i][j] = 0
                    elif c == '#':
                        self.cells[i][j] = 1
                    else:
                        continue
                    j += 1
                if j != width:
                    raise Exception("Size Error. Map width = ", j, ", but must be", width )
                i += 1

        if i != height:
            raise Exception("Size Error. Map height = ", i, ", but must be", height )
    
    def SetGridCells(self, width, height, gridCells):
        '''
        Initialization of map by list of cells.
        '''
        self.width = width
        self.height = height
        self.cells = gridCells

    def InBounds(self, i, j):
        '''
        Check if the cell is on a grid.
        '''
        return (0 <= j < self.width) and (0 <= i < self.height)
    
    def Traversable(self, i, j):
        '''
        Check if the cell is not an obstacle.
        '''
        return not self.cells[i][j]

    def GetNeighbours(self, i, j):
        '''
        Returns a list of neighbouring cells as (i,j) tuples. 
        Fucntions should returns such neighbours, that allows both cardinal and diagonal moves, 
        but dissalows cutting corners and squezzing. 

        Parameters:
            i, j (int, int): Position on the grid map, for which neighbours are needed

        Returns:
            neighbours(list[(int, int)]): List of neighbours grid map (i, j) coordinates.   
        '''
        neighbors = []
        for ki in range(i - 1, i + 2):
            for kj in range(j - 1, j + 2):
                if ((i, j) != (ki, kj) and self.InBounds(ki, kj) and self.Traversable(ki, kj)):
                    if (abs(ki + kj - i - j) == 1):
                        neighbors.append((ki, kj))
                    elif (True):
                        if (self.Traversable(i, kj) and self.Traversable(ki, j)):
                            neighbors.append((ki, kj))
                    #neighbors.append((ki, kj))
        return neighbors

    def CalculateCost(self, i1, j1, i2, j2):
        '''                    
        Computes cost of simple moves between cells on grid, 
        or euclidean distance, if there isnt a simple move between cells

        Args:
            i1, j1 (int, int): Positions of first cell on the grid map
            i2, j2 (int, int): Positions of first cell on the grid map
   

        Returns:
            [float]: cost of simple moves or euclidean distance.   
        '''

        if(abs(i1 - i2) + abs(j1 - j2) == 2):
            return 1.41421356237
        elif (abs(i1 - i2) + abs(j1 - j2) == 1):
            return 1.0
        else:
            return math.sqrt(abs(i1 - i2) ** 2 + abs(j1 - j2) ** 2)

# %%
class Node:
    '''
    Class represents a grid search node

    - i, j: coordinates of corresponding grid element
    - g: g-value of the node
    - h: h-value of the node
    - F: f-value of the node
    - parent: pointer to the parent-node 
    '''

    def __init__(self, coord, g = math.inf, h = math.inf, F = None, parent = None):
        self.i = coord[0]
        self.j = coord[1]
        self.g = float(g)
        self.h = float(h)
        if F is None:
            self.F = self.g + h
        else:
            self.F = F        
        self.parent = parent
    
    def __eq__(self, other):
        return (self.i == other.i) and (self.j == other.j)
    
    def __lt__(self, other):
        return (self.F < other.F) or ((self.F == other.F) and (self.g < other.g))

# %%
def EuclidDistance(node1, node2):
    '''
    Returns a euclidean distance between cells corresponding to nodes
    '''
    return math.sqrt((node1.i - node2.i) ** 2 + (node1.j - node2.j) ** 2)

# %%
def MakePath(goal):
    '''
    Creates a path by tracing parent pointers from the goal node to the start node
    It also returns path's length.
    '''

    length = goal.g
    current = goal
    path = []
    while current.parent:
        path.append(current)
        current = current.parent
    path.append(current)
    return path[::-1], length

# %% [markdown]
# ## Implementing OPEN and CLOSED

# %%
class Open:

    def __init__(self):
        self.elements = dict()
        self.sortF = dict()


    def __iter__(self):
        return iter(self.elements)


    def __len__(self):
        return len(self.elements)

    def IsEmpty(self):
        '''
        IsEmpty should inform whether the OPEN is exhausted or not in the former case the search main loop should be interrupted
        '''
        return self.__len__() == 0

    def AddNode(self, item : Node, *args):
        '''
        AddNode is the method that puts (e.g. inserts or updates) the node to OPEN
        When implementing it do not forget to handle all possible cases:
         - node already in OPEN but the new g-value is better;
         - node already in OPEN but the new g-value is worse;
         - node is not in OPEN yet.
        '''
        el = self.elements.get((item.i, item.j))
        if el:
            if el.g > item.g:
                mn = el.F
                self.elements[(item.i, item.j)] = Node((item.i, item.j), item.g, item.h, item.F, item.parent)
                self.sortF[mn].remove((item.i, item.j))
                if (len(self.sortF[mn]) == 0):
                    self.sortF.pop(mn)

                if self.sortF.get(item.F):
                    self.sortF.update({item.F: self.sortF[item.F] + [(item.i, item.j)]})
                else:
                    self.sortF.update({item.F: [(item.i, item.j)]})
            return
        self.elements.update({(item.i, item.j): item})

        if self.sortF.get(item.F):
            self.sortF.update({item.F: self.sortF[item.F] + [(item.i, item.j)]})
        else:
            self.sortF.update({item.F: [(item.i, item.j)]})
        return

    def GetBestNode(self, *args):
        '''
        GetBestNode is the method that 
         i) finds the best node, i.e. the one with the lowest f-value (f=g+h) (for Dijkstra h=0),
         ii) removes it from OPEN and 
         iii) returns it
        '''
        mn = min(self.sortF)
        k = self.sortF[mn][0]
        if (len(self.sortF[mn])) == 1:
            self.sortF.pop(mn)
        else:
            self.sortF.update({mn: self.sortF[mn][1:]})
        best = self.elements.pop(k)
        return best
    
    def UniteAndUpdate(self, other, newWeight):
        '''
        Unite Open set with other container and update F-values of nodes with new weight:
        
        f(Node) = g(Node) + weignt * h(Node)
        '''

        self.elements.update(other.elements)
        self.sortF.clear()

        #other.elements.clear()
        #other.sortF.clear()

        for i in self.elements:
            self.elements[i].F = self.elements[i].g + newWeight * self.elements[i].h
            if self.sortF.get(self.elements[i].F):
                self.sortF.update({self.elements[i].F: self.sortF[self.elements[i].F] + [i]})
            else:
                self.sortF.update({self.elements[i].F: [i]})

    def WasExpanded(self, item : Node):
        '''
        WasExpanded is the method that checks if a node has been expanded
        '''
        return (item.i, item.j) in self.elements

    def GetNode(self, i, j):
        '''
        Finds node from Closed set by (i, j) coordinates on grid and returns it. Returns None if node was not found.
        '''
        if self.WasExpanded(Node((i, j))):
            return self.elements[(i, j)]
        else:
            return None

# %%
class Closed:
    
    def __init__(self):
        self.elements = dict()


    def __iter__(self):
        return iter(self.elements)


    def __len__(self):
        return len(self.elements)


    def AddNode(self, item : Node):
        '''
        AddNode is the method that inserts the node to CLOSED
        '''
        self.elements.update({(item.i, item.j): item})


    def WasExpanded(self, item : Node):
        '''
        WasExpanded is the method that checks if a node has been expanded
        '''
        return (item.i, item.j) in self.elements

    def GetNode(self, i, j):
        '''
        Finds node from Closed set by (i, j) coordinates on grid and returns it. Returns None if node was not found.
        '''
        if self.WasExpanded(Node((i, j))):
            return self.elements[(i, j)]
        else:
            return None

# %% [markdown]
# ## Weighted A*

# %%
def WAStar(startCoord, goalCoord, gridMap, hFunc, weight):
    '''
    Runs weighted A* search algorithm without re-expansion on any domain.

    Parameters:
        startCoord (tuple(int, int)): The start state of search in useful for your implementation form.
        goalCoord (tuple(int, int)): The goal state of search in useful for your implementation form.
        gridMap: An additional domain information (such as grid map).
        hFunc (function): The heuristics function for currently using domain.
        weight (float): The weight of heuristics in F-value computation.

    Returns:
        pathFound (bool): Path was found or not.   
        lastNode (Node): The last node in path. None if path was not found.
    '''

    OPEN = Open()
    CLOSED = Closed()
    start = Node(startCoord, g = 0, h = 0, F = 0)
    OPEN.AddNode(start)
    while not OPEN.IsEmpty():
        curNode = OPEN.GetBestNode()
        CLOSED.AddNode(curNode)
        if ((curNode.i, curNode.j) == goalCoord):
            return True, curNode
        neighbors = gridMap.GetNeighbours(curNode.i, curNode.j)
        for n in neighbors:
            newNode = Node(n)
            newNode.g = curNode.g + gridMap.CalculateCost(curNode.i, curNode.j, newNode.i, newNode.j)
            newNode.h = hFunc(newNode, Node(goalCoord))
            newNode.F = newNode.g + weight * newNode.h
            newNode.parent = curNode
            if CLOSED.WasExpanded(newNode):
                continue
            OPEN.AddNode(newNode)
    return False, None

# %% [markdown]
# ## Naive Anytime A*

# %%
def NaiveATAStar(startCoord, goalCoord, gridMap, hFunc, startWeight = 3.0, stepWeight = 0.5):
    '''
    Repeatedly runs weighted A* search algorithm without re-expansion on any domain, 
    decreasing current weight from startWeight to 1.0 by stepWeight.

    Parameters:
        startCoord (tuple(int, int)): The start state of search in useful for your implementation form.
        goalCoord (tuple(int, int)): The goal state of search in useful for your implementation form.
        gridMap: An additional domain information (such as grid map).
        hFunc (function): The heuristics function for currently using domain.
        startWeigth (float): The initial weight of heuristics in F-value computation. Must be greater or equal to 1.0
        stepWeigth (float): The value by which the weight will be reduced, if it is provided by the algorithm 

    Returns:
        pathFound (bool): Path was found or not.   
        lastNode (Node): The last node in path. None if path was not found.
    '''

    weight = startWeight if (startWeight >= 1) else 1
    result = WAStar(startCoord, goalCoord, gridMap, hFunc, weight)
    yield result

    while True:
        result = WAStar(startCoord, goalCoord, gridMap, hFunc, weight)
        yield result
        if weight <= 1:
            break
        weight = (weight - stepWeight) if (weight - stepWeight) >= 1 else 1

# %% [markdown]
# ## Anytime Repairing A*

# %%
def ComputeActualWeight(OPEN, INCONS, weight, goalNode):
    minOpen = math.inf
    minIncons = math.inf
    OP = Open()
    OP.UniteAndUpdate(OPEN, 1)
    EN = Open()
    EN.UniteAndUpdate(INCONS, 1)
    if not OPEN.IsEmpty():
        minOpen = min(OP.sortF)#min(v.g + v.h for v in OPEN)
    if not INCONS.IsEmpty():
        minIncons = min(EN.sortF)#min(v.g + v.h for v in INCONS)
    minG = min(minOpen, minIncons)

    return min(weight, goalNode.g / minG)

def ImprovePath(goalNode, gridMap, hFunc, OPEN:Open, INCONS:Open, CLOSED:Closed, VISITED:Open, weight):
#TODO
    '''
    Runs a modified version of weighted A* search algorithm without re-expansion on any domain.

    Parameters:
        goalNode: The goal state.
        gridMap: An additional domain information (such as grid map).
        hFunc (function): The heuristics function for currently using domain.
        weight (float): The weight of heuristics in F-value computation.

    Returns:
        pathFound (bool): Path was found or not.
        lastNode (Node): The last node in path. None if path was not found.
    '''
    #if (weight <= 1):
    #    print('goalNode.g = ', goalNode.g)
    #print("Improve path", end=' ')
    while (goalNode.g > min(OPEN.sortF)):
        curNode = OPEN.GetBestNode()
        #if (weight <= 1):
        #    print('{:5.3f} {:5.3f} {:5.3f} {:5.3f}'.format(curNode.i, curNode.j, curNode.g, curNode.F))
        CLOSED.AddNode(curNode)
        if ((curNode.i, curNode.j) == (goalNode.i, goalNode.j)):
            #print(goalNode.g)
            #print('complete ', curNode.g)
            return True, curNode, OPEN, INCONS, CLOSED, VISITED
        neighbors = gridMap.GetNeighbours(curNode.i, curNode.j)
        for n in neighbors:
            newNode = VISITED.GetNode(n[0], n[1])
            if not newNode:
                newNode = Node(n)

            if (newNode.g > curNode.g + gridMap.CalculateCost(curNode.i, curNode.j, newNode.i, newNode.j)):
                newNode.g = curNode.g + gridMap.CalculateCost(curNode.i, curNode.j, newNode.i, newNode.j)
                newNode.h = hFunc(newNode, Node((goalNode.i, goalNode.j)))
                newNode.F = newNode.g + weight * newNode.h
                newNode.parent = curNode
                if CLOSED.WasExpanded(newNode):
                    INCONS.AddNode(newNode)
                else:
                    OPEN.AddNode(newNode)
            VISITED.AddNode(newNode)
    #print(goalNode.g)
    #print('complete')
    return True, goalNode, OPEN, INCONS, CLOSED, VISITED


def ARAStar(startCoord, goalCoord, gridMap, hFunc, startWeight = 3.0, stepWeight = 0.5):
    '''
    Runs Anytime Repairing A* search algorithm.

    Parameters:
        startCoord (tuple(int, int)): The start state of search in useful for your implementation form.
        goalCoord (tuple(int, int)): The goal state of search in useful for your implementation form.
        gridMap: An additional domain information (such as grid map).
        hFunc (function): The heuristics function for currently using domain.
        startWeigth (float): The initial weight of heuristics in F-value computation. Must be greater or equal to 1.0
        stepWeigth (float): The value by which the weight will be reduced, if it is provided by the algorithm  (not used)

    Returns:
        pathFound (bool): Path was found or not.
        lastNode (Node): The last node in path. None if path was not found.
    '''
    OPEN = Open()
    INCONS = Open()
    CLOSED = Closed()
    VISITED = Open()
    start = Node(startCoord, g = 0)
    finish = Node(goalCoord)
    start.h = hFunc(start, Node(goalCoord))
    start.F = start.g + startWeight * start.h
    finish.h = 0
    finish.F = finish.g + startWeight * start.h
    OPEN.AddNode(start)
    weight = startWeight
    #print('Before: ', OPEN.elements.keys(), ' ', INCONS.elements.keys(), ' ', CLOSED.elements.keys())
    flag, lnd, OPEN, INCONS, CLOSED, VISITED = ImprovePath(finish, gridMap, hFunc, OPEN, INCONS, CLOSED, VISITED, weight)
    #print('finish.g = ', lnd.F)
    finish = Node((lnd.i, lnd.j), h=lnd.h, g=lnd.g, F=lnd.F, parent=lnd.parent)
    #print('After: ', OPEN.elements.keys(), ' ', INCONS.elements.keys(), ' ', CLOSED.elements.keys())
    check = ComputeActualWeight(OPEN, INCONS, weight, finish)
    yield (flag, finish)

    while check > 1:
        weight -= stepWeight
        weight = min(check, weight)
        weight = max(1.0, weight)
        OPEN.UniteAndUpdate(INCONS, weight)
        INCONS.elements.clear()
        INCONS.sortF.clear()
        CLOSED.elements.clear()
        #print('Before: ', OPEN.elements.keys(), ' ', INCONS.elements.keys(), ' ', CLOSED.elements.keys())
        flag, lnd, OPEN, INCONS, CLOSED, VISITED = ImprovePath(finish, gridMap, hFunc, OPEN, INCONS, CLOSED, VISITED, weight)
        finish = Node((lnd.i, lnd.j), h=lnd.h, g=lnd.g, F=lnd.F, parent=lnd.parent)
        #print('After: ', OPEN.elements.keys(), ' ', INCONS.elements.keys(), ' ', CLOSED.elements.keys())
        #print('finish.g = ', finish.g)
        #print(weight)
        check = ComputeActualWeight(OPEN, INCONS, weight, finish)
        #print('goalNode.g = ', finish.g)
        #print('check = ', check)
        yield (flag, finish)

# %% [markdown]
# # Experiment

# %%
def SimpleTest(SearchGenerator, task, heuristicFunction, startWeigth, stepWeigth, maxTime):
    '''
    SimpleTest runs SearchGenerator on one task (use a number from 0 to 25 to 
    choose a certain debug task on simple map or None to choose a random task 
    from this pool) with *args as optional arguments and displays:
     - 'Path found!' and some statistics -- path was found
     - 'Path not found!' -- path was not found
     - 'Execution error' -- an error occurred while executing the SearchFunction In first two cases function also draws visualisation of the task

    Parameters:
        SearchGenerator (generator):
        task (int):
        heuristicFunction (function): The heuristics function for currently using domain.
        startWeigth (float): The initial weight of heuristics in F-value computation. Must be greater or equal to 1.0
        stepWeigth (float): The value by which the weight will be reduced, if it is provided by the algorithm 
        maxTime (float): The amount of time given for the pathfinding procedure. Set in seconds.  

    Returns:
        pathFound (bool): Path was found or not.   
        length (Node): The length of the last found path.
        w (int): The sub-optimality value of the last found path.. 
    '''
    
    height = 15
    width = 30
    mapstr = '''
. . . # # . . . . . . . . # # . . . # . . # # . . . . . . .  
. . . # # # # # . . # . . # # . . . . . . # # . . . . . . . 
. . . . . . . # . . # . . # # . . . # . . # # . . . . . . . 
. . . # # . . # . . # . . # # . . . # . . # # . . . . . . . 
. . . # # . . # . . # . . # # . . . # . . # # . . . . . . . 
. . . # # . . # . . # . . # # . . . # . . # # # # # . . . . 
. . . # # . . # . . # . . # # . . . # . . # # # # # . . . . 
. . . . . . . # . . # . . # # . . . # . . # . . . . . . . . 
. . . # # . . # . . # . . # # . . . # . . # . . . . . . . . 
. . . # # . . # . . # . . # # . . . # . . # . . . . . . . . 
. . . # # . . . . . # . . . . . . . # . . . . . . . . . . . 
. . . # # # # # # # # # # # # # . # # . # # # # # # # . # # 
. . . # # . . . . . . . . # # . . . . . . . . . . . . . . . 
. . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
. . . # # . . . . . . . . # # . . . . . . . . . . . . . . .
'''

    taskMap = Map()
    taskMap.ReadFromString(mapstr, width, height)
    starts = [(0, 1), (6, 2), (5, 6), (13, 7), (4, 23)]
    goals = [(1, 28), (2, 29), (3, 20), (3, 20), (0, 0)]
    lengths = [47.8994949, 40.8994949, 38.2426407, 21.8284271, 47.4852814]

    if (task is None) or not (0 <= task < 5):
        task = randint(0, 4)

    start = Node(starts[task])
    goal = Node(goals[task])
    length = lengths[task]

    trueResult = WAStar((start.i, start.j), (goal.i, goal.j), taskMap, heuristicFunction, 1) 
    path = MakePath(trueResult[1])
    print("A* Path found! Length: {:.7f}. Correct: {:s}".format(path[1], str(abs(path[1] - length) < 1e-6)))

    start_time = time.time()
    lastResult = False, None

    iter_count = 0
    timer = 0.0
    finale_timer = 0.0
    w = 0.0
    for result in SearchGenerator((start.i, start.j), (goal.i, goal.j), taskMap, heuristicFunction, startWeigth, stepWeigth):
        iter_count += 1
        timer = time.time() - start_time
        
        if timer < maxTime:
            lastResult = result
            finale_timer = timer
            if lastResult[0]:
                wLength = lastResult[1].g
                w = wLength / length
                #print(iter_count, "iter. Real sub-optimality value: {:.5f}".format(w))
                print("{:2d} iter. Real sub-optimality value: {:.5f}".format(iter_count, w))
                if w - 1 < EPS:
                    break
            else:
                #print(iter_count, "iter. Weighted path not found!")
                print("{} iter. Weighted path not found!".format(iter_count))
        else:
            break
    
    if lastResult[0]:
        wLength = lastResult[1].g
        w = wLength/length
        print("Weighted path found! Finale sub-optimality value: {:.7f}. Iterations: {:d}. Time: {:.7}".format(w, iter_count, finale_timer))
        return True, wLength, w
    else:
        print("Weighted path not found!")
        return False, math.inf, math.inf

# %%
for i in range(5):
    SimpleTest(NaiveATAStar, i, EuclidDistance, 5, 0.05, 0.5)
# Out:
# A* Path found! Length: 47.8994949. Correct: True
#  1 iter. Real sub-optimality value: 1.60692
#  2 iter. Real sub-optimality value: 1.60692
#  3 iter. Real sub-optimality value: 1.60692
#  4 iter. Real sub-optimality value: 1.60692
#  5 iter. Real sub-optimality value: 1.60692
#  6 iter. Real sub-optimality value: 1.60692
#  7 iter. Real sub-optimality value: 1.60692
#  8 iter. Real sub-optimality value: 1.60692
#  9 iter. Real sub-optimality value: 1.60692
# 10 iter. Real sub-optimality value: 1.60692
# 11 iter. Real sub-optimality value: 1.60692
# 12 iter. Real sub-optimality value: 1.60692
# 13 iter. Real sub-optimality value: 1.60692
# 14 iter. Real sub-optimality value: 1.60692
# 15 iter. Real sub-optimality value: 1.60692
# 16 iter. Real sub-optimality value: 1.35133
# 17 iter. Real sub-optimality value: 1.35133
# 18 iter. Real sub-optimality value: 1.35133
# 19 iter. Real sub-optimality value: 1.35133
# 20 iter. Real sub-optimality value: 1.35133
# 21 iter. Real sub-optimality value: 1.35133
# 22 iter. Real sub-optimality value: 1.35133
# 23 iter. Real sub-optimality value: 1.35133
# 24 iter. Real sub-optimality value: 1.35133
# 25 iter. Real sub-optimality value: 1.35133
# 26 iter. Real sub-optimality value: 1.35133
# 27 iter. Real sub-optimality value: 1.35133
# 28 iter. Real sub-optimality value: 1.35133
# 29 iter. Real sub-optimality value: 1.35133
# 30 iter. Real sub-optimality value: 1.35133
# 31 iter. Real sub-optimality value: 1.35133
# 32 iter. Real sub-optimality value: 1.35133
# 33 iter. Real sub-optimality value: 1.35133
# 34 iter. Real sub-optimality value: 1.35133
# 35 iter. Real sub-optimality value: 1.35133
# 36 iter. Real sub-optimality value: 1.35133
# 37 iter. Real sub-optimality value: 1.35133
# 38 iter. Real sub-optimality value: 1.35133
# 39 iter. Real sub-optimality value: 1.35133
# 40 iter. Real sub-optimality value: 1.35133
# 41 iter. Real sub-optimality value: 1.35133
# 42 iter. Real sub-optimality value: 1.35133
# 43 iter. Real sub-optimality value: 1.35133
# 44 iter. Real sub-optimality value: 1.35133
# 45 iter. Real sub-optimality value: 1.35133
# 46 iter. Real sub-optimality value: 1.35133
# 47 iter. Real sub-optimality value: 1.35133
# 48 iter. Real sub-optimality value: 1.35133
# 49 iter. Real sub-optimality value: 1.35133
# 50 iter. Real sub-optimality value: 1.35133
# 51 iter. Real sub-optimality value: 1.35133
# 52 iter. Real sub-optimality value: 1.01730
# 53 iter. Real sub-optimality value: 1.01730
# 54 iter. Real sub-optimality value: 1.01730
# 55 iter. Real sub-optimality value: 1.01730
# 56 iter. Real sub-optimality value: 1.01730
# 57 iter. Real sub-optimality value: 1.01730
# 58 iter. Real sub-optimality value: 1.01730
# 59 iter. Real sub-optimality value: 1.01730
# 60 iter. Real sub-optimality value: 1.01730
# Weighted path found! Finale sub-optimality value: 1.0172951. Iterations: 61. Time: 0.4956646
# A* Path found! Length: 40.8994949. Correct: True
#  1 iter. Real sub-optimality value: 1.71079
#  2 iter. Real sub-optimality value: 1.71079
#  3 iter. Real sub-optimality value: 1.71079
#  4 iter. Real sub-optimality value: 1.71079
#  5 iter. Real sub-optimality value: 1.71079
#  6 iter. Real sub-optimality value: 1.71079
#  7 iter. Real sub-optimality value: 1.71079
#  8 iter. Real sub-optimality value: 1.71079
#  9 iter. Real sub-optimality value: 1.71079
# 10 iter. Real sub-optimality value: 1.71079
# 11 iter. Real sub-optimality value: 1.71079
# 12 iter. Real sub-optimality value: 1.71079
# 13 iter. Real sub-optimality value: 1.71079
# 14 iter. Real sub-optimality value: 1.71079
# 15 iter. Real sub-optimality value: 1.71079
# 16 iter. Real sub-optimality value: 1.71079
# 17 iter. Real sub-optimality value: 1.71079
# 18 iter. Real sub-optimality value: 1.71079
# 19 iter. Real sub-optimality value: 1.41146
# 20 iter. Real sub-optimality value: 1.41146
# 21 iter. Real sub-optimality value: 1.41146
# 22 iter. Real sub-optimality value: 1.41146
# 23 iter. Real sub-optimality value: 1.41146
# 24 iter. Real sub-optimality value: 1.41146
# 25 iter. Real sub-optimality value: 1.41146
# 26 iter. Real sub-optimality value: 1.41146
# 27 iter. Real sub-optimality value: 1.41146
# 28 iter. Real sub-optimality value: 1.41146
# 29 iter. Real sub-optimality value: 1.41146
# 30 iter. Real sub-optimality value: 1.41146
# 31 iter. Real sub-optimality value: 1.41146
# 32 iter. Real sub-optimality value: 1.41146
# 33 iter. Real sub-optimality value: 1.41146
# 34 iter. Real sub-optimality value: 1.41146
# 35 iter. Real sub-optimality value: 1.41146
# 36 iter. Real sub-optimality value: 1.41146
# 37 iter. Real sub-optimality value: 1.41146
# 38 iter. Real sub-optimality value: 1.41146
# 39 iter. Real sub-optimality value: 1.41146
# 40 iter. Real sub-optimality value: 1.41146
# 41 iter. Real sub-optimality value: 1.41146
# 42 iter. Real sub-optimality value: 1.41146
# 43 iter. Real sub-optimality value: 1.41146
# 44 iter. Real sub-optimality value: 1.41146
# 45 iter. Real sub-optimality value: 1.41146
# 46 iter. Real sub-optimality value: 1.41146
# 47 iter. Real sub-optimality value: 1.41146
# 48 iter. Real sub-optimality value: 1.41146
# 49 iter. Real sub-optimality value: 1.41146
# 50 iter. Real sub-optimality value: 1.41146
# 51 iter. Real sub-optimality value: 1.41146
# 52 iter. Real sub-optimality value: 1.41146
# 53 iter. Real sub-optimality value: 1.41146
# 54 iter. Real sub-optimality value: 1.02026
# 55 iter. Real sub-optimality value: 1.02026
# 56 iter. Real sub-optimality value: 1.02026
# 57 iter. Real sub-optimality value: 1.02026
# 58 iter. Real sub-optimality value: 1.02026
# 59 iter. Real sub-optimality value: 1.02026
# 60 iter. Real sub-optimality value: 1.02026
# 61 iter. Real sub-optimality value: 1.02026
# 62 iter. Real sub-optimality value: 1.02026
# 63 iter. Real sub-optimality value: 1.02026
# 64 iter. Real sub-optimality value: 1.02026
# 65 iter. Real sub-optimality value: 1.02026
# 66 iter. Real sub-optimality value: 1.02026
# 67 iter. Real sub-optimality value: 1.02026
# 68 iter. Real sub-optimality value: 1.02026
# 69 iter. Real sub-optimality value: 1.02026
# 70 iter. Real sub-optimality value: 1.02026
# 71 iter. Real sub-optimality value: 1.02026
# 72 iter. Real sub-optimality value: 1.02026
# 73 iter. Real sub-optimality value: 1.02026
# 74 iter. Real sub-optimality value: 1.02026
# 75 iter. Real sub-optimality value: 1.02026
# 76 iter. Real sub-optimality value: 1.00000
# Weighted path found! Finale sub-optimality value: 1.0000000. Iterations: 76. Time: 0.4636908
# A* Path found! Length: 38.2426407. Correct: True
#  1 iter. Real sub-optimality value: 1.23085
#  2 iter. Real sub-optimality value: 1.23085
#  3 iter. Real sub-optimality value: 1.23085
#  4 iter. Real sub-optimality value: 1.23085
#  5 iter. Real sub-optimality value: 1.23085
#  6 iter. Real sub-optimality value: 1.23085
#  7 iter. Real sub-optimality value: 1.23085
#  8 iter. Real sub-optimality value: 1.23085
#  9 iter. Real sub-optimality value: 1.23085
# 10 iter. Real sub-optimality value: 1.23085
# 11 iter. Real sub-optimality value: 1.23085
# 12 iter. Real sub-optimality value: 1.23085
# 13 iter. Real sub-optimality value: 1.23085
# 14 iter. Real sub-optimality value: 1.23085
# 15 iter. Real sub-optimality value: 1.23085
# 16 iter. Real sub-optimality value: 1.23085
# 17 iter. Real sub-optimality value: 1.23085
# 18 iter. Real sub-optimality value: 1.23085
# 19 iter. Real sub-optimality value: 1.23085
# 20 iter. Real sub-optimality value: 1.23085
# 21 iter. Real sub-optimality value: 1.23085
# 22 iter. Real sub-optimality value: 1.23085
# 23 iter. Real sub-optimality value: 1.23085
# 24 iter. Real sub-optimality value: 1.23085
# 25 iter. Real sub-optimality value: 1.23085
# 26 iter. Real sub-optimality value: 1.23085
# 27 iter. Real sub-optimality value: 1.23085
# 28 iter. Real sub-optimality value: 1.23085
# 29 iter. Real sub-optimality value: 1.23085
# 30 iter. Real sub-optimality value: 1.23085
# 31 iter. Real sub-optimality value: 1.23085
# 32 iter. Real sub-optimality value: 1.23085
# 33 iter. Real sub-optimality value: 1.23085
# 34 iter. Real sub-optimality value: 1.23085
# 35 iter. Real sub-optimality value: 1.23085
# 36 iter. Real sub-optimality value: 1.23085
# 37 iter. Real sub-optimality value: 1.23085
# 38 iter. Real sub-optimality value: 1.23085
# 39 iter. Real sub-optimality value: 1.23085
# 40 iter. Real sub-optimality value: 1.23085
# 41 iter. Real sub-optimality value: 1.23085
# 42 iter. Real sub-optimality value: 1.23085
# 43 iter. Real sub-optimality value: 1.23085
# 44 iter. Real sub-optimality value: 1.23085
# 45 iter. Real sub-optimality value: 1.23085
# 46 iter. Real sub-optimality value: 1.23085
# 47 iter. Real sub-optimality value: 1.23085
# 48 iter. Real sub-optimality value: 1.23085
# 49 iter. Real sub-optimality value: 1.23085
# 50 iter. Real sub-optimality value: 1.23085
# 51 iter. Real sub-optimality value: 1.23085
# 52 iter. Real sub-optimality value: 1.23085
# 53 iter. Real sub-optimality value: 1.23085
# 54 iter. Real sub-optimality value: 1.23085
# 55 iter. Real sub-optimality value: 1.23085
# 56 iter. Real sub-optimality value: 1.23085
# 57 iter. Real sub-optimality value: 1.23085
# 58 iter. Real sub-optimality value: 1.23085
# 59 iter. Real sub-optimality value: 1.23085
# 60 iter. Real sub-optimality value: 1.23085
# 61 iter. Real sub-optimality value: 1.23085
# 62 iter. Real sub-optimality value: 1.23085
# 63 iter. Real sub-optimality value: 1.23085
# 64 iter. Real sub-optimality value: 1.23085
# 65 iter. Real sub-optimality value: 1.23085
# 66 iter. Real sub-optimality value: 1.11094
# 67 iter. Real sub-optimality value: 1.11094
# 68 iter. Real sub-optimality value: 1.11094
# 69 iter. Real sub-optimality value: 1.11094
# 70 iter. Real sub-optimality value: 1.11094
# 71 iter. Real sub-optimality value: 1.08928
# 72 iter. Real sub-optimality value: 1.00000
# Weighted path found! Finale sub-optimality value: 1.0000000. Iterations: 72. Time: 0.2878063
# A* Path found! Length: 21.8284271. Correct: True
#  1 iter. Real sub-optimality value: 1.19436
#  2 iter. Real sub-optimality value: 1.19436
#  3 iter. Real sub-optimality value: 1.19436
#  4 iter. Real sub-optimality value: 1.19436
#  5 iter. Real sub-optimality value: 1.19436
#  6 iter. Real sub-optimality value: 1.19436
#  7 iter. Real sub-optimality value: 1.19436
#  8 iter. Real sub-optimality value: 1.19436
#  9 iter. Real sub-optimality value: 1.19436
# 10 iter. Real sub-optimality value: 1.19436
# 11 iter. Real sub-optimality value: 1.19436
# 12 iter. Real sub-optimality value: 1.19436
# 13 iter. Real sub-optimality value: 1.19436
# 14 iter. Real sub-optimality value: 1.19436
# 15 iter. Real sub-optimality value: 1.19436
# 16 iter. Real sub-optimality value: 1.19436
# 17 iter. Real sub-optimality value: 1.19436
# 18 iter. Real sub-optimality value: 1.19436
# 19 iter. Real sub-optimality value: 1.19436
# 20 iter. Real sub-optimality value: 1.19436
# 21 iter. Real sub-optimality value: 1.19436
# 22 iter. Real sub-optimality value: 1.19436
# 23 iter. Real sub-optimality value: 1.19436
# 24 iter. Real sub-optimality value: 1.19436
# 25 iter. Real sub-optimality value: 1.19436
# 26 iter. Real sub-optimality value: 1.19436
# 27 iter. Real sub-optimality value: 1.19436
# 28 iter. Real sub-optimality value: 1.19436
# 29 iter. Real sub-optimality value: 1.19436
# 30 iter. Real sub-optimality value: 1.19436
# 31 iter. Real sub-optimality value: 1.19436
# 32 iter. Real sub-optimality value: 1.19436
# 33 iter. Real sub-optimality value: 1.19436
# 34 iter. Real sub-optimality value: 1.19436
# 35 iter. Real sub-optimality value: 1.19436
# 36 iter. Real sub-optimality value: 1.19436
# 37 iter. Real sub-optimality value: 1.19436
# 38 iter. Real sub-optimality value: 1.19436
# 39 iter. Real sub-optimality value: 1.19436
# 40 iter. Real sub-optimality value: 1.19436
# 41 iter. Real sub-optimality value: 1.19436
# 42 iter. Real sub-optimality value: 1.19436
# 43 iter. Real sub-optimality value: 1.19436
# 44 iter. Real sub-optimality value: 1.19436
# 45 iter. Real sub-optimality value: 1.19436
# 46 iter. Real sub-optimality value: 1.19436
# 47 iter. Real sub-optimality value: 1.19436
# 48 iter. Real sub-optimality value: 1.19436
# 49 iter. Real sub-optimality value: 1.19436
# 50 iter. Real sub-optimality value: 1.19436
# 51 iter. Real sub-optimality value: 1.19436
# 52 iter. Real sub-optimality value: 1.19436
# 53 iter. Real sub-optimality value: 1.19436
# 54 iter. Real sub-optimality value: 1.19436
# 55 iter. Real sub-optimality value: 1.19436
# 56 iter. Real sub-optimality value: 1.19436
# 57 iter. Real sub-optimality value: 1.19436
# 58 iter. Real sub-optimality value: 1.19436
# 59 iter. Real sub-optimality value: 1.19436
# 60 iter. Real sub-optimality value: 1.19436
# 61 iter. Real sub-optimality value: 1.19436
# 62 iter. Real sub-optimality value: 1.19436
# 63 iter. Real sub-optimality value: 1.19436
# 64 iter. Real sub-optimality value: 1.19436
# 65 iter. Real sub-optimality value: 1.19436
# 66 iter. Real sub-optimality value: 1.19436
# 67 iter. Real sub-optimality value: 1.19436
# 68 iter. Real sub-optimality value: 1.15641
# 69 iter. Real sub-optimality value: 1.15641
# 70 iter. Real sub-optimality value: 1.15641
# 71 iter. Real sub-optimality value: 1.15641
# 72 iter. Real sub-optimality value: 1.00000
# Weighted path found! Finale sub-optimality value: 1.0000000. Iterations: 72. Time: 0.09593821
# A* Path found! Length: 47.4852814. Correct: True
#  1 iter. Real sub-optimality value: 1.63688
#  2 iter. Real sub-optimality value: 1.63688
#  3 iter. Real sub-optimality value: 1.63688
#  4 iter. Real sub-optimality value: 1.63688
#  5 iter. Real sub-optimality value: 1.63688
#  6 iter. Real sub-optimality value: 1.63688
#  7 iter. Real sub-optimality value: 1.63688
#  8 iter. Real sub-optimality value: 1.63688
#  9 iter. Real sub-optimality value: 1.63688
# 10 iter. Real sub-optimality value: 1.63688
# 11 iter. Real sub-optimality value: 1.04212
# 12 iter. Real sub-optimality value: 1.04212
# 13 iter. Real sub-optimality value: 1.04212
# 14 iter. Real sub-optimality value: 1.04212
# 15 iter. Real sub-optimality value: 1.04212
# 16 iter. Real sub-optimality value: 1.04212
# 17 iter. Real sub-optimality value: 1.04212
# 18 iter. Real sub-optimality value: 1.04212
# 19 iter. Real sub-optimality value: 1.04212
# 20 iter. Real sub-optimality value: 1.37906
# 21 iter. Real sub-optimality value: 1.37906
# 22 iter. Real sub-optimality value: 1.37906
# 23 iter. Real sub-optimality value: 1.37906
# 24 iter. Real sub-optimality value: 1.37906
# 25 iter. Real sub-optimality value: 1.04212
# 26 iter. Real sub-optimality value: 1.04212
# 27 iter. Real sub-optimality value: 1.02978
# 28 iter. Real sub-optimality value: 1.02978
# 29 iter. Real sub-optimality value: 1.02978
# 30 iter. Real sub-optimality value: 1.02978
# 31 iter. Real sub-optimality value: 1.02978
# 32 iter. Real sub-optimality value: 1.02978
# 33 iter. Real sub-optimality value: 1.02978
# 34 iter. Real sub-optimality value: 1.02978
# 35 iter. Real sub-optimality value: 1.02978
# 36 iter. Real sub-optimality value: 1.02978
# 37 iter. Real sub-optimality value: 1.02978
# 38 iter. Real sub-optimality value: 1.02978
# 39 iter. Real sub-optimality value: 1.02978
# 40 iter. Real sub-optimality value: 1.02978
# 41 iter. Real sub-optimality value: 1.02978
# 42 iter. Real sub-optimality value: 1.01745
# 43 iter. Real sub-optimality value: 1.01745
# 44 iter. Real sub-optimality value: 1.01745
# 45 iter. Real sub-optimality value: 1.01745
# 46 iter. Real sub-optimality value: 1.01745
# 47 iter. Real sub-optimality value: 1.01745
# 48 iter. Real sub-optimality value: 1.01745
# 49 iter. Real sub-optimality value: 1.01745
# 50 iter. Real sub-optimality value: 1.01745
# 51 iter. Real sub-optimality value: 1.01745
# 52 iter. Real sub-optimality value: 1.01745
# 53 iter. Real sub-optimality value: 1.01745
# 54 iter. Real sub-optimality value: 1.01745
# 55 iter. Real sub-optimality value: 1.01745
# 56 iter. Real sub-optimality value: 1.01745
# 57 iter. Real sub-optimality value: 1.01745
# 58 iter. Real sub-optimality value: 1.01745
# 59 iter. Real sub-optimality value: 1.01745
# 60 iter. Real sub-optimality value: 1.00000
# Weighted path found! Finale sub-optimality value: 1.0000000. Iterations: 60. Time: 0.4556656

# %%
for i in range(5):
    SimpleTest(ARAStar, i, EuclidDistance, 5, 0.05, 0.1)
# Out:
# A* Path found! Length: 47.8994949. Correct: True
#  1 iter. Real sub-optimality value: 1.60692
#  2 iter. Real sub-optimality value: 1.60692
#  3 iter. Real sub-optimality value: 1.60692
#  4 iter. Real sub-optimality value: 1.60692
#  5 iter. Real sub-optimality value: 1.60692
#  6 iter. Real sub-optimality value: 1.08351
#  7 iter. Real sub-optimality value: 1.06621
#  8 iter. Real sub-optimality value: 1.00000
# Weighted path found! Finale sub-optimality value: 1.0000000. Iterations: 8. Time: 0.02401614
# A* Path found! Length: 40.8994949. Correct: True
#  1 iter. Real sub-optimality value: 1.71079
#  2 iter. Real sub-optimality value: 1.71079
#  3 iter. Real sub-optimality value: 1.71079
#  4 iter. Real sub-optimality value: 1.71079
#  5 iter. Real sub-optimality value: 1.09780
#  6 iter. Real sub-optimality value: 1.07755
#  7 iter. Real sub-optimality value: 1.00000
# Weighted path found! Finale sub-optimality value: 1.0000000. Iterations: 7. Time: 0.0159936
# A* Path found! Length: 38.2426407. Correct: True
#  1 iter. Real sub-optimality value: 1.23085
#  2 iter. Real sub-optimality value: 1.23085
#  3 iter. Real sub-optimality value: 1.23085
#  4 iter. Real sub-optimality value: 1.23085
#  5 iter. Real sub-optimality value: 1.02166
#  6 iter. Real sub-optimality value: 1.02166
#  7 iter. Real sub-optimality value: 1.00000
# Weighted path found! Finale sub-optimality value: 1.0000000. Iterations: 7. Time: 0.007992268
# A* Path found! Length: 21.8284271. Correct: True
#  1 iter. Real sub-optimality value: 1.19436
#  2 iter. Real sub-optimality value: 1.19436
#  3 iter. Real sub-optimality value: 1.00000
# Weighted path found! Finale sub-optimality value: 1.0000000. Iterations: 3. Time: 0.0
# A* Path found! Length: 47.4852814. Correct: True
#  1 iter. Real sub-optimality value: 1.64922
#  2 iter. Real sub-optimality value: 1.64922
#  3 iter. Real sub-optimality value: 1.64922
#  4 iter. Real sub-optimality value: 1.03489
#  5 iter. Real sub-optimality value: 1.01745
#  6 iter. Real sub-optimality value: 1.01745
#  7 iter. Real sub-optimality value: 1.01745
#  8 iter. Real sub-optimality value: 1.00000
# Weighted path found! Finale sub-optimality value: 1.0000000. Iterations: 8. Time: 0.01599407
